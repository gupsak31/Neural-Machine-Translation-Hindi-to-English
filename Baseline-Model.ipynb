# %% [markdown]
# # **Setup**
#
# ---
#
#
#
#
# *   Connect with Gdrive.
# *   Download and load libraries/packages.

# %%
SOS_token = 0
EOS_token = 1
UKN_token = 2
MAX_LENGTH = 500
teacher_forcing_ratio = 0.5
random_trainData = False
N_Epochs = 3

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/CS779:\ Competition
# Out:
# /content/gdrive/MyDrive/CS779: Competition

# %%
import numpy as np
import pandas as pd

import time
import math
import random

import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker

import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

from sklearn.model_selection import train_test_split

# %%
# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on =", device)
# Out:
# Running on = cuda

# %% [markdown]
# Setup SpaCy
#
# ---

# %%
# !python3 -m spacy download en >> /dev/null

# %%
import spacy
eng = spacy.load("en_core_web_sm")

# %% [markdown]
# Setup indicnlp library
#
# ---

# %%
#### Ony run to download the indic library (first time only) 
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_library >> /dev/null
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git >> /dev/null

# %%
# !pip install Morfessor >> /dev/null

# %%
# The path to the local git repo for Indic NLP library
INDIC_NLP_LIB_HOME = "indic_nlp_library"

# The path to the local git repo for Indic NLP Resources
INDIC_NLP_RESOURCES = "indic_nlp_resources"

# Add Library to Python path
import sys
sys.path.append(r"{}".format(INDIC_NLP_LIB_HOME))

# Set environment variable
from indicnlp import common
common.set_resources_path(INDIC_NLP_RESOURCES)

# Initialize the Indic NLP library
from indicnlp import loader
loader.load()

# %%
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory

# %% [markdown]
# Setup iNLTK library
#
# ---

# %%
# !pip install inltk >> /dev/null

# %%
from inltk.inltk import setup
'''
Note: Run setup('<code-of-language>') to a language for the FIRST TIME ONLY.
This will download all the necessary models required to do inference for that language.
'''
try:
    setup("hi")
except:
    print("Downloading 'hindi' setup... Wait before running next cell!")
# Out:
# Downloading 'hindi' setup... Wait before running next cell!

# %%
from inltk.inltk import tokenize as inltk_tokenize

# %% [markdown]
# Setup NLTK library - For evaluation
#
# ---

# %%
# !pip install -U nltk >> /dev/null

# %%
import nltk
nltk.download('wordnet')

from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.meteor_score import single_meteor_score
# Out:
# Downloading Model. This might take time, depending on your internet connection. Please be patient.
# We'll only do this for the first time.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # **Load Data**
#
#
# ---
#
#
#
# *   Load training data
# *   Load Embedding matrix, word2index and index2word for Hindi

# %%
df = pd.read_csv("train/train.csv")
df = df[["hindi", "english"]]
display(df.head(5))
print("\nTotal hindi-english sentence pairs = ", df.shape[0])
# Out:
#                                                hindi                                            english
# 0  एल सालवाडोर मे, जिन दोनो पक्षों ने सिविल-युद्ध...  In El Salvador, both sides that withdrew from ...
# 1                मैं उनके साथ कोई लेना देना नहीं है.                    I have nothing to do with them.
# 2                                         -हटाओ रिक.                                   Fuck them, Rick.
# 3               क्योंकि यह एक खुशियों भरी फ़िल्म है.                         Because it's a happy film.
# 4                   The thought reaching the eyes...                   The thought reaching the eyes...
# Total hindi-english sentence pairs =  102322

# %%
# #####################################################################
# #### Testing on smaller data
# #####################################################################
# df = df[:500]

# %%
my_embeddings = np.load("hindi_embeddings.npy")
word2index_npy = np.load("word2index.npy")
index2word_npy = np.load("index2word.npy")

# %%
hindi_word2index = {}
hindi_index2word = {}

for i in range(len(word2index_npy)):
    hindi_word2index[word2index_npy[i, 0]] = int(word2index_npy[i, 1])

for i in range(len(index2word_npy)):
    hindi_index2word[int(index2word_npy[i, 0])] = index2word_npy[i, 1]

# %% [markdown]
# # **Data Normalisation and Pre-processing**
#
# ---
#
# *   Remove nuktas from Hindi sentences.
# *   Create **embedding matrix** using iNLTK library.

# %%
factory = IndicNormalizerFactory()
normalizer = factory.get_normalizer("hi", remove_nuktas = True)

for i, pair in df.iterrows():
    df.iloc[i, 0] = normalizer.normalize(pair[0])

    if(i != 0 and i%10000 == 0):
        print("Iterations done =", i)
print("...Done")
# Out:
# Iterations done = 10000
# Iterations done = 20000
# Iterations done = 30000
# Iterations done = 40000
# Iterations done = 50000
# Iterations done = 60000
# Iterations done = 70000
# Iterations done = 80000
# Iterations done = 90000
# Iterations done = 100000
# ...Done

# %%
class Language:
    def __init__(self, name):
        self.name = name
        if (name == "english"):
            self.n_words = 3  # UKN, SOS and EOS
            self.word2index = {"<sos>":0, "<eos>":1, "<ukn>":2}
            self.index2word = {0: "<sos>", 1: "<eos>", 2: "<ukn>"}
        elif (name == "hindi"):
            self.n_words = len(hindi_word2index)
            self.word2index = hindi_word2index
            self.index2word = hindi_index2word

    def addSentence(self, sentence):
        tokens = eng(sentence)
        for token in tokens:
            self.addWord(token.text)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.index2word[self.n_words] = word
            self.n_words += 1

# %%
def readData():
    print("Reading data...")
    pairs = [[sent for sent in pair] for _, pair in df.iterrows()]
    input_lang = Language("hindi")
    output_lang = Language("english")

    print("Data normalisation...")
    #############################################################################
    ### Add normalising techniques
    #############################################################################

    print("Data preprocessing...")
    for i, pair in enumerate(pairs):
        output_lang.addSentence(pair[1])

        if(i != 0 and i%10000 == 0):
            print("Iterations done = ", i)
    print("... Done")

    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = readData()
# Out:
# Reading data...
# Data normalisation...
# Data preprocessing...
# Iterations done =  10000
# Iterations done =  20000
# Iterations done =  30000
# Iterations done =  40000
# Iterations done =  50000
# Iterations done =  60000
# Iterations done =  70000
# Iterations done =  80000
# Iterations done =  90000
# Iterations done =  100000
# ... Done

# %% [markdown]
# # **Utility Functions**
#
# ---

# %%
def asMinutes(s):
    m = math.floor(s/60)
    s -= m*60
    return '%dm %ds' %(m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s/(percent)
    rs = es - s
    return "Time Elapsed - %s (Expected time remaining - %s)\n" %(asMinutes(s), asMinutes(rs))

# %%
def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base = 0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.show();

# %%
def indexesFromSentence(lang, sentence):
    idx_list = []
    if (lang.name == "english"):
        tokens = eng(sentence)
        for token in tokens:
            if token.text in lang.word2index:
                idx_list.append(lang.word2index[token.text])
            else:
                idx_list.append(UKN_token)
    else:
        tokens = inltk_tokenize(sentence, "hi")
        for token in tokens:
                if token in lang.word2index:
                    idx_list.append(lang.word2index[token])
                else:
                    idx_list.append(UKN_token)
                    print("No token in emb.", lang.name, token)
    return idx_list

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype = torch.long, device = device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
data = np.reshape(np.random.randn(2*df.shape[0]),(df.shape[0], 2)) # 10 training examples
labels = np.random.randint(2, size = df.shape[0]) # 10 labels
X = pd.DataFrame(data, columns = ['Column_1', 'Column_2'])
y = pd.Series(labels)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

train_indexes = list(X_train.index)
test_indexes = list(X_test.index)

# %%
test_df = df.iloc[test_indexes]
# validation_pairs = [tensorsFromPair(list(test_df.iloc[i])) for i in range(test_df.shape[0])]
validation_pairs = torch.load("val.pt")

train_df = df.iloc[train_indexes]
# train_pairs = [[sent for sent in pair] for _, pair in train_df.iterrows()]
# train_pairs = [tensorsFromPair(train_pairs[idx]) for idx in range(len(train_pairs))]
train_pairs = torch.load("train.pt")

# %%
def inputData(n_iter):
    if (random_trainData == True):
        train = random.choice(train_pairs)
    else:
        idx = int((n_iter - 1) - train_df.shape[0]*int((n_iter - 1)/train_df.shape[0]))
        train = train_pairs[idx]
    return train

# %% [markdown]
# # **Model**
#
# ---

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()

        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.embedding.from_pretrained(torch.from_numpy(my_embeddings), freeze = True)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        # print("input encoder = ", input.shape)
        embedded = self.embedding(input)
        embedded = embedded.view(1, 1, -1)
        # print("embedded encoder = ", embedded.shape)
        output, hidden = self.gru(embedded, hidden)
        # print("out, hid encoder = ", output.shape, hidden.shape)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device = device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim = 1)

    def forward(self, input, hidden):
        # print("input decoder = ", input.shape)
        output = self.embedding(input).view(1, 1, -1)
        # print("output decoder = ", output.shape)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device = device)

# %% [markdown]
# # **Train**
#
# ---

# %%
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length = MAX_LENGTH):
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_hidden = encoder.initHidden()
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device = device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)

    decoder_input = torch.tensor([[SOS_token]], device = device)
    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item()/target_length

# %%
def validate(validation_pairs, encoder, decoder, criterion, max_length = MAX_LENGTH):
    with torch.no_grad():
        val_loss = 0

        for i in range(int(len(validation_pairs)/2)):
            input_tensor = validation_pairs[i][0]
            target_tensor = validation_pairs[i][1]

            input_length = input_tensor.size(0)
            target_length = target_tensor.size(0)

            encoder_hidden = encoder.initHidden()
            encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device = device)

            loss = 0
            for ei in range(input_length):
                encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)

            decoder_input = torch.tensor([[SOS_token]], device = device)
            decoder_hidden = encoder_hidden

            for di in range(target_length):
                decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
                topv, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze().detach()  # detach from history as input

                loss += criterion(decoder_output, target_tensor[di])
                if decoder_input.item() == EOS_token:
                    break
        val_loss += loss.item()/target_length

    return val_loss

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience = 10, verbose = False):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf

    def __call__(self, val_loss, enc, dec):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, enc, dec)
        elif score < self.best_score:
            self.counter += 1
            print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, enc, dec)
            self.counter = 0

    def save_checkpoint(self, val_loss, enc, dec):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f"Validation loss decreased ({self.val_loss_min:.5f} --> {val_loss:.5f}).  Saving model ...")
        torch.save(enc.state_dict(), "encoder.pt")
        torch.save(dec.state_dict(), "decoder.pt")
        self.val_loss_min = val_loss

# %%
def trainIters(encoder, decoder, n_iters = 0, print_every = 1000, plot_every = 100, val_every = 1, learning_rate = 0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr = learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr = learning_rate)
    # training_pairs, validation_pairs = inputData(n_iters)
    criterion = nn.NLLLoss()
    early_stopping = EarlyStopping(patience = 3, verbose = True)

    for iter in range(1, n_iters + 1):
        # training_pair = training_pairs[iter - 1]
        training_pair = inputData(iter)

        input_tensor = training_pair[0].to(device)
        target_tensor = training_pair[1].to(device)

        # print(input_tensor.shape, target_tensor.shape)
        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter%print_every == 0:
            print_loss_avg = print_loss_total/print_every
            print_loss_total = 0
            print("%sIterations completed - %d (%d%%)\nLoss = %.4f\n" %(timeSince(start, iter/n_iters), iter, iter/n_iters*100, print_loss_avg))

        if iter%plot_every == 0:
            plot_loss_avg = plot_loss_total/plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

        if iter%val_every == 0:
            val_loss = validate(validation_pairs, encoder, decoder, criterion)
            print("Validate loss = ", val_loss, "\n")

            early_stopping(val_loss, encoder, decoder)
        
            # if early_stopping.early_stop:
            #     print("Early stopping")
            #     break
        
    torch.save(encoder.state_dict(), "encoder_last.pt")
    torch.save(decoder.state_dict(), "decoder_last.pt")
    showPlot(plot_losses)

# %%
hidden_size = 400
encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = DecoderRNN(hidden_size, output_lang.n_words).to(device)

trainIters(encoder, decoder, n_iters = N_Epochs*train_df.shape[0], print_every = 10000, plot_every = 1000, val_every = 20000)
# Out:
# Time Elapsed - 8m 1s (Expected time remaining - 213m 50s)
# Iterations completed - 10000 (3%)
# Loss = 4.8928
#
# Time Elapsed - 16m 38s (Expected time remaining - 213m 8s)
# Iterations completed - 20000 (7%)
# Loss = 4.5703
#
# Validate loss =  4.740001678466797
#
# Validation loss decreased (inf --> 4.74000).  Saving model ...
# Time Elapsed - 25m 59s (Expected time remaining - 213m 18s)
# Iterations completed - 30000 (10%)
# Loss = 4.3820
#
# Time Elapsed - 34m 37s (Expected time remaining - 204m 29s)
# Iterations completed - 40000 (14%)
# Loss = 4.2902
#
# Validate loss =  3.9529294967651367
#
# Validation loss decreased (4.74000 --> 3.95293).  Saving model ...
# Time Elapsed - 43m 59s (Expected time remaining - 199m 3s)
# Iterations completed - 50000 (18%)
# Loss = 4.2085
#
# Time Elapsed - 52m 36s (Expected time remaining - 189m 39s)
# Iterations completed - 60000 (21%)
# Loss = 4.1299
#
# Validate loss =  2.4829049110412598
#
# Validation loss decreased (3.95293 --> 2.48290).  Saving model ...
# Time Elapsed - 61m 58s (Expected time remaining - 182m 37s)
# Iterations completed - 70000 (25%)
# Loss = 4.1298
#
# Time Elapsed - 70m 41s (Expected time remaining - 173m 25s)
# Iterations completed - 80000 (28%)
# Loss = 4.1058
#
# Validate loss =  4.427250385284424
#
# EarlyStopping counter: 1 out of 3
# Time Elapsed - 80m 21s (Expected time remaining - 166m 18s)
# Iterations completed - 90000 (32%)
# Loss = 4.0877
#
# Time Elapsed - 89m 2s (Expected time remaining - 156m 56s)
# Iterations completed - 100000 (36%)
# Loss = 3.9777
#
# Validate loss =  4.664722442626953
#
# EarlyStopping counter: 2 out of 3
# Time Elapsed - 98m 35s (Expected time remaining - 149m 1s)
# Iterations completed - 110000 (39%)
# Loss = 4.0011
#
# Time Elapsed - 107m 17s (Expected time remaining - 139m 42s)
# Iterations completed - 120000 (43%)
# Loss = 3.9383
#
# Validate loss =  5.85957670211792
#
# EarlyStopping counter: 3 out of 3
# Time Elapsed - 116m 43s (Expected time remaining - 131m 19s)
# Iterations completed - 130000 (47%)
# Loss = 3.8844
#
# Time Elapsed - 125m 27s (Expected time remaining - 122m 7s)
# Iterations completed - 140000 (50%)
# Loss = 3.8713
#
# Validate loss =  5.954754829406738
#
# EarlyStopping counter: 4 out of 3
# Time Elapsed - 134m 53s (Expected time remaining - 113m 32s)
# Iterations completed - 150000 (54%)
# Loss = 3.8233
#
# Time Elapsed - 143m 40s (Expected time remaining - 104m 24s)
# Iterations completed - 160000 (57%)
# Loss = 3.8343
#
# Validate loss =  5.994646072387695
#
# EarlyStopping counter: 5 out of 3
# Time Elapsed - 153m 14s (Expected time remaining - 95m 47s)
# Iterations completed - 170000 (61%)
# Loss = 3.8201
#
# Time Elapsed - 162m 2s (Expected time remaining - 86m 39s)
# Iterations completed - 180000 (65%)
# Loss = 3.8193
#
# Validate loss =  5.127159595489502
#
# EarlyStopping counter: 6 out of 3
# Time Elapsed - 171m 38s (Expected time remaining - 77m 56s)
# Iterations completed - 190000 (68%)
# Loss = 3.7740
#
# Time Elapsed - 180m 32s (Expected time remaining - 68m 50s)
# Iterations completed - 200000 (72%)
# Loss = 3.8083
#
# Validate loss =  5.0221076011657715
#
# EarlyStopping counter: 7 out of 3
# Time Elapsed - 190m 8s (Expected time remaining - 59m 59s)
# Iterations completed - 210000 (76%)
# Loss = 3.7360
#
# Time Elapsed - 198m 55s (Expected time remaining - 50m 52s)
# Iterations completed - 220000 (79%)
# Loss = 3.7026
#
# Validate loss =  4.370401382446289
#
# EarlyStopping counter: 8 out of 3
# Time Elapsed - 208m 32s (Expected time remaining - 41m 56s)
# Iterations completed - 230000 (83%)
# Loss = 3.6828
#
# Time Elapsed - 217m 7s (Expected time remaining - 32m 48s)
# Iterations completed - 240000 (86%)
# Loss = 3.6246
#
# Validate loss =  5.2998504638671875
#
# EarlyStopping counter: 9 out of 3
# Time Elapsed - 226m 44s (Expected time remaining - 23m 49s)
# Iterations completed - 250000 (90%)
# Loss = 3.6281
#
# Time Elapsed - 235m 32s (Expected time remaining - 14m 44s)
# Iterations completed - 260000 (94%)
# Loss = 3.7079
#
# Validate loss =  5.403801918029785
#
# EarlyStopping counter: 10 out of 3
# Time Elapsed - 245m 9s (Expected time remaining - 5m 41s)
# Iterations completed - 270000 (97%)
# Loss = 3.6681
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-78a2ce6eb8d6> in <module>()
#       3 decoder = DecoderRNN(hidden_size, output_lang.n_words).to(device)
#       4
# ----> 5 trainIters(encoder, decoder, n_iters = N_Epochs*train_df.shape[0], print_every = 10000, plot_every = 1000, val_every = 20000)
#
# <ipython-input-39-0c03a909fc36> in trainIters(encoder, decoder, n_iters, print_every, plot_every, val_every, learning_rate)
#      43             #     break
#      44
# ---> 45     torch.save(enc.state_dict(), "encoder_last.pt")
#      46     torch.save(dec.state_dict(), "decoder_last.pt")
#      47     showPlot(plot_losses)
#
# NameError: name 'enc' is not defined

# %%
torch.save(encoder.state_dict(), "encoder_last.pt")
torch.save(decoder.state_dict(), "decoder_last.pt")

# %% [markdown]
# # **Evaluation**
#
# ---

# %%
def evaluate(encoder, decoder, sentence, max_length = MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device = device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device = device)  # SOS
        decoder_hidden = encoder_hidden

        decoded_words = []

        for di in range(max_length):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                # decoded_words.append('<eos>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words

# %%
def evaluateRandomly(encoder, decoder, n = 100):
    total_bleu_scores = 0
    total_meteor_scores = 0

    for i in range(n):
        pair = random.choice(pairs)
        # print('>', pair[0])
        # print('=', pair[1])
        output_words = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        # print('<', output_sentence)
        total_bleu_scores += sentence_bleu(pair[1].split(" "), output_sentence.split(" "))
        total_meteor_scores += single_meteor_score(pair[1], output_sentence)
        # print('')
        print(i)

    bleu_result = total_bleu_scores/n
    meteor_result = total_meteor_scores/n
    print("bleu score: ",bleu_result)
    print("meteor score: ",meteor_result)

# %%
evaluateRandomly(encoder, decoder, n = 100)

# %% [markdown]
# # **Submission**
#
# ---

# %%
test = pd.read_csv("test_week1.csv")

# %%
def evaluateTest():
    encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
    decoder = DecoderRNN(hidden_size, output_lang.n_words).to(device)
    encoder.load_state_dict(torch.load("encoder_last.pt"))
    decoder.load_state_dict(torch.load("decoder_last.pt"))
    file1 = open("week1.txt", 'w')
    for i, data in test.iterrows():
        print(i)
        sentence = data["hindi"]
        output_words = evaluate(encoder, decoder, sentence)
        output_sentence = ' '.join(output_words)
        file1.writelines(output_sentence + " \n")

# %%
evaluateTest()
# Out:
# Streaming output truncated to the last 5000 lines.
# 1164
# 1165
# 1166
# 1167
# No token in emb. hindi ▁खड़ा
# No token in emb. hindi ▁बड़ा
# 1168
# 1169
# 1170
# No token in emb. hindi ड़ा
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# No token in emb. hindi ▁उड़
# 1177
# 1178
# 1179
# 1180
# No token in emb. hindi |
# 1181
# 1182
# 1183
# No token in emb. hindi ▁फ़र्क
# 1184
# 1185
# 1186
# 1187
# No token in emb. hindi ▁फ़िर
# No token in emb. hindi ▁तरफ़
# No token in emb. hindi ▁फ़िर
# No token in emb. hindi ▁दूरभाष
# 1188
# No token in emb. hindi ▁बढ़ी
# 1189
# 1190
# 1191
# 1192
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# No token in emb. hindi |
# No token in emb. hindi |
# 1204
# 1205
# 1206
# No token in emb. hindi |
# 1207
# No token in emb. hindi ़ी
# No token in emb. hindi |
# 1208
# 1209
# 1210
# 1211
# No token in emb. hindi |
# 1212
# 1213
# 1214
# 1215
# No token in emb. hindi ▁अंग्रेज़
# 1216
# 1217
# 1218
# No token in emb. hindi ▁पड़
# No token in emb. hindi ▁ज़्यादा
# 1219
# 1220
# 1221
# No token in emb. hindi ज़ा
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# No token in emb. hindi ▁|
# 1237
# 1238
# No token in emb. hindi ज़ा
# No token in emb. hindi ज़
# 1239
# 1240
# 1241
# No token in emb. hindi ▁आवाज़
# No token in emb. hindi ▁वर्णक्रम
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# No token in emb. hindi ▁|
# 1248
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# No token in emb. hindi |
# 1259
# 1260
# 1261
# 1262
# 1263
# No token in emb. hindi ▁ख़राब
# 1264
# 1265
# 1266
# 1267
# 1268
# No token in emb. hindi ▁सब्सिडी
# 1269
# No token in emb. hindi कण
# No token in emb. hindi ▁पड़ोस
# 1270
# 1271
# 1272
# No token in emb. hindi ▁आंकड़ों
# 1273
# 1274
# 1275
# 1276
# No token in emb. hindi ▁सिर्फ़
# 1277
# 1278
# No token in emb. hindi ▁बड़ा
# 1279
# No token in emb. hindi ▁लड़के
# 1280
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# No token in emb. hindi |
# 1289
# 1290
# 1291
# 1292
# 1293
# 1294
# 1295
# 1296
# 1297
# No token in emb. hindi ▁पड़
# No token in emb. hindi |
# 1298
# 1299
# No token in emb. hindi ▁लड़का
# 1300
# 1301
# No token in emb. hindi ▁तरफ़
# 1302
# 1303
# 1304
# 1305
# No token in emb. hindi |
# 1306
# No token in emb. hindi ▁अपघटित
# No token in emb. hindi धात्विक
# 1307
# No token in emb. hindi ▁काफ़ी
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# No token in emb. hindi ▁लड़
# No token in emb. hindi ़
# No token in emb. hindi ▁जोड़ा
# No token in emb. hindi ज़
# No token in emb. hindi ज़
# 1318
# 1319
# No token in emb. hindi ▁थोड़ा
# 1320
# 1321
# 1322
# No token in emb. hindi ▁लड़ाई
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# No token in emb. hindi ▁हज़ारों
# No token in emb. hindi ▁छोड़
# 1339
# 1340
# 1341
# 1342
# 1343
# No token in emb. hindi ▁रोज़गार
# No token in emb. hindi ▁ख़ुद
# No token in emb. hindi ▁लड़ने
# No token in emb. hindi ख़रीद
# 1344
# No token in emb. hindi ▁भाषणों
# 1345
# 1346
# 1347
# No token in emb. hindi ज़ा
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# No token in emb. hindi ▁इज़
# 1360
# No token in emb. hindi ▁बड़ा
# 1361
# 1362
# 1363
# No token in emb. hindi ज़
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# No token in emb. hindi पार्टमेन्ट
# No token in emb. hindi फ़
# No token in emb. hindi ▁फ़्रै
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# No token in emb. hindi ▁जिब्राल्टर
# 1381
# 1382
# 1383
# No token in emb. hindi ▁लड़कियों
# 1384
# 1385
# No token in emb. hindi ▁बढ़ाना
# 1386
# 1387
# 1388
# No token in emb. hindi ▁जोड़े
# 1389
# 1390
# 1391
# No token in emb. hindi ▁आवाज़
# 1392
# 1393
# 1394
# 1395
# 1396
# No token in emb. hindi ▁ज़रूरत
# 1397
# No token in emb. hindi |
# 1398
# 1399
# No token in emb. hindi ▁हटाकर
# 1400
# 1401
# 1402
# No token in emb. hindi ▁ज़रूरत
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# No token in emb. hindi परीक्षण
# 1409
# 1410
# 1411
# 1412
# No token in emb. hindi ▁चार्टर्ड
# 1413
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 1414
# No token in emb. hindi ▁तूफ़ान
# No token in emb. hindi ▁पड़ेगा
# 1415
# No token in emb. hindi ़
# 1416
# 1417
# No token in emb. hindi ▁ज़रूरत
# 1418
# 1419
# 1420
# No token in emb. hindi ▁फ़र्क
# No token in emb. hindi ़
# No token in emb. hindi ▁पड़ा
# No token in emb. hindi ▁फ़र्क
# No token in emb. hindi ़
# No token in emb. hindi ▁पड़ा
# 1421
# No token in emb. hindi ▁चमड़ी
# 1422
# 1423
# No token in emb. hindi ▁सीढ़ियां
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# No token in emb. hindi ▁पड़ा
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# No token in emb. hindi ▁पढ़ना
# 1446
# No token in emb. hindi कणों
# No token in emb. hindi ▁फ़र्श
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# No token in emb. hindi ▁पेड़
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# No token in emb. hindi ▁बढ़
# No token in emb. hindi ▁बढ़ाने
# 1467
# No token in emb. hindi ▁लड़का
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# No token in emb. hindi ▁|
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# No token in emb. hindi लीज़
# 1501
# 1502
# 1503
# No token in emb. hindi ▁पीड़ित
# 1504
# 1505
# 1506
# 1507
# 1508
# No token in emb. hindi |
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# No token in emb. hindi ▁लड़कियों
# 1518
# 1519
# 1520
# 1521
# No token in emb. hindi ज़
# 1522
# 1523
# 1524
# 1525
# No token in emb. hindi ▁खड़ा
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# No token in emb. hindi ▁बढ़
# 1533
# No token in emb. hindi ▁बड़ी
# 1534
# No token in emb. hindi ▁पढ़ने
# 1535
# No token in emb. hindi ▁हज़ार
# 1536
# No token in emb. hindi ▁चीज़
# 1537
# No token in emb. hindi ज़रूरी
# 1538
# 1539
# 1540
# 1541
# 1542
# 1543
# 1544
# 1545
# 1546
# 1547
# 1548
# No token in emb. hindi ▁छोड़
# No token in emb. hindi ▁छोड़ना
# 1549
# No token in emb. hindi ▁चीज़ें
# 1550
# 1551
# No token in emb. hindi ▁मेज़बान
# 1552
# 1553
# 1554
# 1555
# 1556
# 1557
# 1558
# 1559
# 1560
# No token in emb. hindi ▁आँकड़े
# No token in emb. hindi ▁सिफ़ारिश
# 1561
# 1562
# 1563
# No token in emb. hindi ▁लड़ाई
# 1564
# 1565
# 1566
# 1567
# 1568
# 1569
# No token in emb. hindi ▁पड़ा
# 1570
# No token in emb. hindi ▁बढ़ेगा
# 1571
# 1572
# No token in emb. hindi ▁छोड़
# 1573
# 1574
# 1575
# 1576
# 1577
# 1578
# 1579
# 1580
# 1581
# 1582
# 1583
# 1584
# 1585
# 1586
# No token in emb. hindi ▁|
# 1587
# 1588
# No token in emb. hindi ▁बढ़ेगा
# 1589
# 1590
# 1591
# 1592
# 1593
# No token in emb. hindi ▁बढ़ा
# 1594
# 1595
# No token in emb. hindi ▁आल्प्स
# 1596
# 1597
# No token in emb. hindi ▁बाढ़
# 1598
# No token in emb. hindi ▁सिक
# No token in emb. hindi ▁सिक
# 1599
# No token in emb. hindi |
# No token in emb. hindi |
# 1600
# 1601
# No token in emb. hindi |
# 1602
# 1603
# 1604
# No token in emb. hindi ▁छोड़कर
# 1605
# 1606
# 1607
# No token in emb. hindi ▁थोड़ा
# No token in emb. hindi ▁दौड़
# 1608
# 1609
# 1610
# No token in emb. hindi ▁चीज़ों
# No token in emb. hindi ▁|
# 1611
# No token in emb. hindi ▁तोड़ा
# 1612
# 1613
# 1614
# 1615
# 1616
# 1617
# 1618
# No token in emb. hindi ▁डिज़ाइन
# 1619
# No token in emb. hindi ▁ख़राब
# No token in emb. hindi ▁|
# 1620
# 1621
# 1622
# 1623
# 1624
# 1625
# 1626
# No token in emb. hindi ▁बड़ा
# 1627
# 1628
# 1629
# No token in emb. hindi ▁ढ़
# 1630
# 1631
# 1632
# No token in emb. hindi ▁बढ़ावा
# No token in emb. hindi ▁|
# 1633
# 1634
# No token in emb. hindi ▁छोड़
# 1635
# 1636
# 1637
# 1638
# 1639
# 1640
# 1641
# No token in emb. hindi ”
# 1642
# 1643
# 1644
# 1645
# 1646
# No token in emb. hindi |
# 1647
# 1648
# 1649
# 1650
# 1651
# 1652
# 1653
# 1654
# 1655
# 1656
# 1657
# 1658
# 1659
# No token in emb. hindi |
# 1660
# 1661
# 1662
# 1663
# 1664
# 1665
# 1666
# 1667
# 1668
# 1669
# No token in emb. hindi |
# 1670
# 1671
# No token in emb. hindi ▁दृष्
# 1672
# 1673
# 1674
# 1675
# 1676
# 1677
# 1678
# 1679
# 1680
# No token in emb. hindi ▁ऑफ़
# 1681
# 1682
# 1683
# 1684
# No token in emb. hindi आज़म
# 1685
# 1686
# 1687
# 1688
# 1689
# 1690
# 1691
# No token in emb. hindi ▁क्रियाशीलता
# 1692
# No token in emb. hindi ▁|
# 1693
# 1694
# 1695
# 1696
# 1697
# No token in emb. hindi ▁भव्यता
# 1698
# 1699
# 1700
# 1701
# 1702
# 1703
# 1704
# 1705
# 1706
# 1707
# 1708
# No token in emb. hindi ▁पकड़ा
# 1709
# No token in emb. hindi ▁पीढ़ी
# 1710
# No token in emb. hindi सब्ज़
# 1711
# 1712
# 1713
# 1714
# 1715
# 1716
# 1717
# 1718
# 1719
# 1720
# 1721
# 1722
# 1723
# 1724
# 1725
# 1726
# 1727
# 1728
# 1729
# 1730
# 1731
# No token in emb. hindi ▁लड़कियों
# 1732
# 1733
# 1734
# 1735
# 1736
# 1737
# 1738
# 1739
# 1740
# 1741
# 1742
# No token in emb. hindi ़
# No token in emb. hindi ridge
# No token in emb. hindi Stat
# No token in emb. hindi ▁Island
# No token in emb. hindi |
# 1743
# 1744
# 1745
# No token in emb. hindi ▁बड़ा
# 1746
# No token in emb. hindi ▁बूढ़ी
# 1747
# 1748
# 1749
# 1750
# 1751
# 1752
# 1753
# No token in emb. hindi ▁इफेक्ट्स
# No token in emb. hindi ▁|
# 1754
# 1755
# 1756
# 1757
# 1758
# 1759
# No token in emb. hindi ड़
# No token in emb. hindi ड़े
# No token in emb. hindi ▁झगड़ा
# 1760
# 1761
# No token in emb. hindi ▁Corporation
# 1762
# No token in emb. hindi दिव्य
# 1763
# 1764
# 1765
# 1766
# 1767
# No token in emb. hindi ▁सड़कों
# 1768
# 1769
# No token in emb. hindi ▁फ़े
# No token in emb. hindi ▁काफ़ी
# 1770
# No token in emb. hindi ▁ख़ु
# No token in emb. hindi फ़
# 1771
# No token in emb. hindi ▁छोड़
# 1772
# No token in emb. hindi |
# 1773
# 1774
# 1775
# 1776
# 1777
# No token in emb. hindi |
# 1778
# 1779
# 1780
# 1781
# No token in emb. hindi ▁पकड़ने
# 1782
# 1783
# 1784
# 1785
# 1786
# 1787
# 1788
# 1789
# 1790
# 1791
# 1792
# 1793
# 1794
# 1795
# No token in emb. hindi ▁नुक्त
# 1796
# 1797
# 1798
# 1799
# 1800
# No token in emb. hindi ▁फ़र्क
# No token in emb. hindi ▁पड़ता
# 1801
# 1802
# 1803
# 1804
# 1805
# 1806
# 1807
# No token in emb. hindi ▁लड़का
# 1808
# 1809
# 1810
# 1811
# No token in emb. hindi ▁उड़ा
# 1812
# 1813
# No token in emb. hindi ▁खड़ा
# 1814
# 1815
# 1816
# 1817
# 1818
# 1819
# No token in emb. hindi ज़ा
# 1820
# No token in emb. hindi ▁ज़्यादा
# 1821
# 1822
# 1823
# 1824
# No token in emb. hindi ़
# No token in emb. hindi ▁ज़
# 1825
# No token in emb. hindi ▁खड़ी
# 1826
# No token in emb. hindi |
# No token in emb. hindi |
# 1827
# No token in emb. hindi ▁सिर्फ़
# 1828
# No token in emb. hindi ▁आज़ाद
# 1829
# No token in emb. hindi ▁दौड़
# 1830
# No token in emb. hindi ▁गाड़ी
# 1831
# 1832
# No token in emb. hindi ▁कपड़े
# No token in emb. hindi ▁ज़मीन
# No token in emb. hindi बड़े
# 1833
# 1834
# No token in emb. hindi ▁|
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# No token in emb. hindi ▁|
# 1846
# No token in emb. hindi ena
# No token in emb. hindi Government
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# 1853
# No token in emb. hindi ज़ार
# No token in emb. hindi ▁फ़
# 1854
# No token in emb. hindi ▁ज़रूरत
# 1855
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# No token in emb. hindi ब्रू
# 1868
# 1869
# No token in emb. hindi ▁बूढ़े
# 1870
# 1871
# 1872
# No token in emb. hindi ▁|
# 1873
# 1874
# 1875
# No token in emb. hindi ▁बड़ी
# 1876
# No token in emb. hindi ▁लड़की
# No token in emb. hindi ▁सौंपी
# 1877
# 1878
# 1879
# 1880
# 1881
# No token in emb. hindi ▁चढ़
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ज़रिए
# 1891
# 1892
# 1893
# 1894
# 1895
# No token in emb. hindi ▁सिर्फ़
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# No token in emb. hindi ▁|
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# No token in emb. hindi ▁consider
# 1911
# No token in emb. hindi ▁तोड़
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# No token in emb. hindi ▁लड़के
# 1919
# 1920
# 1921
# No token in emb. hindi ▁सीढ़ी
# 1922
# No token in emb. hindi ▁तोड़कर
# 1923
# 1924
# 1925
# 1926
# No token in emb. hindi ▁|
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# No token in emb. hindi ▁|
# 1933
# 1934
# No token in emb. hindi ▁|
# 1935
# 1936
# No token in emb. hindi ▁ज़मीन
# 1937
# 1938
# No token in emb. hindi ज़ी
# 1939
# No token in emb. hindi ▁ढूँढ़
# 1940
# 1941
# 1942
# 1943
# 1944
# No token in emb. hindi ्ज़
# No token in emb. hindi क़
# No token in emb. hindi ैद
# 1945
# No token in emb. hindi ▁बेनेट
# 1946
# 1947
# No token in emb. hindi ▁बढ़ने
# 1948
# 1949
# 1950
# 1951
# 1952
# No token in emb. hindi ़
# No token in emb. hindi ▁सैकड़ों
# 1953
# 1954
# No token in emb. hindi ▁आंकड़े
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# No token in emb. hindi ▁अमेज़न
# No token in emb. hindi ▁जुआन
# 1967
# No token in emb. hindi ▁सफ़ल
# No token in emb. hindi ▁हांग
# 1968
# No token in emb. hindi ल्फ़
# 1969
# 1970
# 1971
# 1972
# 1973
# No token in emb. hindi |
# 1974
# 1975
# No token in emb. hindi ल्फ़
# 1976
# No token in emb. hindi ▁लकड़ी
# 1977
# 1978
# 1979
# 1980
# No token in emb. hindi ▁फ़र्श
# No token in emb. hindi |
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# No token in emb. hindi ▁कुंभ
# 1989
# 1990
# 1991
# 1992
# No token in emb. hindi ▁चीज़ों
# No token in emb. hindi ▁|
# 1993
# 1994
# 1995
# No token in emb. hindi ▁पीढ़ी
# No token in emb. hindi ▁जुड़ी
# No token in emb. hindi ▁|
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# No token in emb. hindi |
# 2006
# 2007
# No token in emb. hindi ▁ऐल्
# No token in emb. hindi फ़ा
# 2008
# No token in emb. hindi ▁सफ़ल
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# No token in emb. hindi ▁पकड़
# 2015
# 2016
# 2017
# No token in emb. hindi ▁बड़ी
# 2018
# 2019
# 2020
# No token in emb. hindi ▁अनिच्छा
# 2021
# 2022
# 2023
# 2024
# No token in emb. hindi ▁|
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# No token in emb. hindi ▁लड़के
# 2033
# 2034
# No token in emb. hindi ▁पकड़ने
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# No token in emb. hindi भाड़
# 2047
# No token in emb. hindi ▁form
# 2048
# No token in emb. hindi ▁ज़िम्मेदारी
# 2049
# No token in emb. hindi ▁नाराज़
# 2050
# 2051
# No token in emb. hindi ▁फ़िर
# No token in emb. hindi ▁नज़र
# 2052
# No token in emb. hindi ▁|
# 2053
# No token in emb. hindi हर्स्ट
# No token in emb. hindi ▁पीड़ितों
# No token in emb. hindi ▁छोड़
# 2054
# 2055
# 2056
# 2057
# 2058
# No token in emb. hindi |
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# 2071
# No token in emb. hindi ▁पकड़ना
# 2072
# 2073
# 2074
# 2075
# 2076
# No token in emb. hindi |
# No token in emb. hindi |
# 2077
# 2078
# No token in emb. hindi ज़ी
# 2079
# No token in emb. hindi ज़ी
# 2080
# No token in emb. hindi |
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# No token in emb. hindi pur
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# No token in emb. hindi ▁इंतज़ा
# 2097
# 2098
# No token in emb. hindi ▁उत्पीड़न
# 2099
# 2100
# No token in emb. hindi |
# 2101
# No token in emb. hindi ज़रूरी
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ज़रूरी
# 2102
# 2103
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# No token in emb. hindi |
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# No token in emb. hindi |
# No token in emb. hindi ▁पकड़ने
# 2130
# 2131
# No token in emb. hindi ज़रूरी
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# 2141
# 2142
# No token in emb. hindi ▁पड़े
# 2143
# 2144
# 2145
# 2146
# No token in emb. hindi |
# 2147
# 2148
# 2149
# 2150
# 2151
# 2152
# No token in emb. hindi ▁|
# 2153
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# No token in emb. hindi |
# 2160
# 2161
# 2162
# 2163
# 2164
# No token in emb. hindi ▁सड़कों
# 2165
# 2166
# No token in emb. hindi ▁चीज़
# 2167
# 2168
# 2169
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# No token in emb. hindi ▁ज़रूर
# 2177
# 2178
# 2179
# No token in emb. hindi ▁पहाड़
# 2180
# 2181
# 2182
# No token in emb. hindi ▁ढूँढ़
# 2183
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
# 2192
# No token in emb. hindi ज़्ज़
# 2193
# 2194
# 2195
# 2196
# No token in emb. hindi ▁जुड़ी
# 2197
# 2198
# No token in emb. hindi “
# 2199
# No token in emb. hindi फ़्ट
# No token in emb. hindi फ़
# No token in emb. hindi ▁फ़
# 2200
# 2201
# 2202
# 2203
# 2204
# No token in emb. hindi ▁कड़ी
# 2205
# 2206
# 2207
# 2208
# 2209
# No token in emb. hindi ▁सड़क
# 2210
# 2211
# 2212
# No token in emb. hindi ▁नज़र
# No token in emb. hindi ▁पड़ती
# 2213
# 2214
# No token in emb. hindi ▁पकड़े
# 2215
# 2216
# 2217
# 2218
# 2219
# 2220
# No token in emb. hindi फ़िलिप
# 2221
# No token in emb. hindi ▁पकड़
# 2222
# 2223
# 2224
# 2225
# 2226
# 2227
# No token in emb. hindi |
# 2228
# 2229
# No token in emb. hindi ▁पड़ेगा
# 2230
# 2231
# 2232
# No token in emb. hindi ड़ा
# 2233
# 2234
# 2235
# No token in emb. hindi ▁सड़क
# 2236
# 2237
# 2238
# 2239
# No token in emb. hindi ▁ज़रूर
# 2240
# 2241
# 2242
# 2243
# 2244
# No token in emb. hindi ▁छुड़ा
# 2245
# No token in emb. hindi ▁आख़िर
# 2246
# No token in emb. hindi ▁छोड़
# 2247
# No token in emb. hindi ▁प्लाजा
# 2248
# 2249
# 2250
# 2251
# 2252
# 2253
# 2254
# 2255
# 2256
# No token in emb. hindi ▁इक्वाडोर
# No token in emb. hindi ▁1958
# 2257
# 2258
# 2259
# 2260
# 2261
# 2262
# 2263
# 2264
# 2265
# 2266
# 2267
# 2268
# No token in emb. hindi ▁फ़िल्मों
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# 2276
# 2277
# 2278
# 2279
# 2280
# 2281
# 2282
# No token in emb. hindi ▁|
# 2283
# 2284
# 2285
# No token in emb. hindi ▁नज़र
# 2286
# 2287
# 2288
# 2289
# 2290
# No token in emb. hindi ▁जुड़ी
# 2291
# 2292
# 2293
# 2294
# 2295
# No token in emb. hindi ▁पड़े
# 2296
# 2297
# No token in emb. hindi ▁ख़त्म
# No token in emb. hindi |
# 2298
# No token in emb. hindi |
# 2299
# 2300
# 2301
# 2302
# No token in emb. hindi ▁फ़ैल
# No token in emb. hindi ▁फ़ैल
# No token in emb. hindi =
# 2303
# 2304
# 2305
# 2306
# 2307
# 2308
# 2309
# 2310
# No token in emb. hindi ▁फ़रवरी
# No token in emb. hindi ▁बढ़ावा
# 2311
# 2312
# 2313
# 2314
# 2315
# 2316
# 2317
# 2318
# 2319
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ▁बड़े
# 2320
# 2321
# 2322
# 2323
# No token in emb. hindi ़
# 2324
# 2325
# 2326
# 2327
# 2328
# 2329
# 2330
# 2331
# 2332
# No token in emb. hindi ▁जुड़
# 2333
# 2334
# No token in emb. hindi |
# 2335
# 2336
# 2337
# 2338
# No token in emb. hindi |
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# No token in emb. hindi ▁|
# 2347
# 2348
# No token in emb. hindi ▁फ़ैला
# 2349
# 2350
# No token in emb. hindi ▁छोड़
# 2351
# 2352
# No token in emb. hindi ▁जयपुर
# No token in emb. hindi गढ़
# 2353
# 2354
# 2355
# 2356
# 2357
# 2358
# 2359
# No token in emb. hindi |
# 2360
# 2361
# 2362
# 2363
# 2364
# 2365
# No token in emb. hindi ▁थोड़ा
# 2366
# 2367
# 2368
# 2369
# 2370
# No token in emb. hindi ▁उड़ा
# 2371
# 2372
# No token in emb. hindi ▁लड़ाई
# 2373
# 2374
# 2375
# 2376
# No token in emb. hindi ▁दौड़
# 2377
# 2378
# 2379
# 2380
# 2381
# 2382
# 2383
# 2384
# No token in emb. hindi ▁पिजिन
# No token in emb. hindi ज़ी
# No token in emb. hindi ▁फ़ेल
# No token in emb. hindi ▁पितामह
# 2385
# 2386
# No token in emb. hindi ▁प्लाजा
# No token in emb. hindi ▁जोड़ती
# 2387
# No token in emb. hindi ▁घोड़े
# 2388
# No token in emb. hindi ▁नाज़ुक
# No token in emb. hindi ▁शेख़
# No token in emb. hindi ज़
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2397
# No token in emb. hindi ज़
# 2398
# No token in emb. hindi ▁तूफ़ान
# 2399
# No token in emb. hindi ▁ख़बर
# 2400
# 2401
# 2402
# No token in emb. hindi ▁ज़्यादा
# 2403
# No token in emb. hindi ▁मतों
# No token in emb. hindi ▁|
# 2404
# 2405
# 2406
# No token in emb. hindi ▁आंकड़े
# 2407
# 2408
# 2409
# 2410
# No token in emb. hindi ▁तबादल
# 2411
# 2412
# 2413
# No token in emb. hindi ▁लॉजिक
# 2414
# 2415
# No token in emb. hindi ▁अभिगम
# No token in emb. hindi ▁2008-09
# 2416
# 2417
# No token in emb. hindi ▁सफ़ल
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# No token in emb. hindi ़
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# No token in emb. hindi ▁संरक्ष
# 2434
# No token in emb. hindi ▁सिफ़ारिश
# 2435
# 2436
# 2437
# 2438
# 2439
# No token in emb. hindi ▁साफ़
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# No token in emb. hindi ▁लड़का
# 2448
# No token in emb. hindi sum
# 2449
# 2450
# 2451
# 2452
# 2453
# 2454
# 2455
# 2456
# 2457
# 2458
# 2459
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 2460
# 2461
# No token in emb. hindi ▁ख़ास
# 2462
# 2463
# 2464
# 2465
# No token in emb. hindi ▁थोड़ा
# No token in emb. hindi ▁बड़े
# 2466
# 2467
# 2468
# 2469
# 2470
# 2471
# No token in emb. hindi ▁सिर्फ़
# 2472
# No token in emb. hindi ▁|
# 2473
# 2474
# No token in emb. hindi ▁यक़ीन
# 2475
# 2476
# 2477
# 2478
# No token in emb. hindi |
# 2479
# 2480
# 2481
# 2482
# 2483
# No token in emb. hindi ▁बढ़
# 2484
# 2485
# No token in emb. hindi ▁बढ़
# 2486
# No token in emb. hindi टैमा
# No token in emb. hindi टैमा
# No token in emb. hindi टैमा
# 2487
# No token in emb. hindi ▁लड़की
# No token in emb. hindi ▁लड़की
# 2488
# No token in emb. hindi ज़ेन
# 2489
# 2490
# No token in emb. hindi ▁लड़कियों
# 2491
# 2492
# 2493
# No token in emb. hindi ▁ट्रूडो
# 2494
# 2495
# No token in emb. hindi ▁ज़
# 2496
# 2497
# 2498
# 2499
# No token in emb. hindi ▁पढ़ा
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# 2506
# No token in emb. hindi फ़
# No token in emb. hindi ▁बड़े
# 2507
# 2508
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# 2515
# 2516
# 2517
# 2518
# No token in emb. hindi ▁|
# 2519
# No token in emb. hindi ▁तेज़ी
# 2520
# No token in emb. hindi आज़म
# 2521
# 2522
# No token in emb. hindi ▁फ़ैला
# 2523
# 2524
# 2525
# 2526
# 2527
# 2528
# 2529
# 2530
# No token in emb. hindi क़
# No token in emb. hindi फ़ी
# 2531
# 2532
# 2533
# 2534
# 2535
# 2536
# 2537
# 2538
# 2539
# 2540
# 2541
# 2542
# 2543
# 2544
# 2545
# 2546
# 2547
# 2548
# No token in emb. hindi ▁सड़क
# No token in emb. hindi ▁छोड़
# 2549
# No token in emb. hindi ▁|
# 2550
# 2551
# No token in emb. hindi ▁कागज़
# No token in emb. hindi |
# 2552
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# No token in emb. hindi ▁बड़ी
# 2559
# No token in emb. hindi फ़ू
# 2560
# 2561
# 2562
# No token in emb. hindi ▁थोड़ा
# No token in emb. hindi ▁छिन
# No token in emb. hindi ▁थोड़ा
# 2563
# No token in emb. hindi ▁बड़े
# 2564
# 2565
# No token in emb. hindi ▁फ़र्क
# No token in emb. hindi ▁|
# 2566
# 2567
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# 2575
# 2576
# 2577
# 2578
# 2579
# No token in emb. hindi ▁ज़्यादा
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# No token in emb. hindi ▁ज़रूरत
# 2589
# 2590
# 2591
# 2592
# 2593
# 2594
# 2595
# 2596
# 2597
# 2598
# 2599
# 2600
# 2601
# 2602
# 2603
# 2604
# 2605
# 2606
# 2607
# 2608
# 2609
# No token in emb. hindi ▁ज़िंदा
# 2610
# 2611
# 2612
# No token in emb. hindi ▁ज़रूरत
# 2613
# No token in emb. hindi ▁घड़ी
# 2614
# 2615
# 2616
# 2617
# No token in emb. hindi ▁बड़े
# 2618
# 2619
# 2620
# No token in emb. hindi |
# 2621
# 2622
# 2623
# 2624
# No token in emb. hindi ▁बढ़ाने
# 2625
# 2626
# 2627
# 2628
# 2629
# 2630
# 2631
# 2632
# 2633
# 2634
# 2635
# No token in emb. hindi ▁लड़की
# 2636
# No token in emb. hindi ▁पड़े
# 2637
# 2638
# 2639
# 2640
# No token in emb. hindi र्जन
# 2641
# No token in emb. hindi ▁0.3
# No token in emb. hindi (३३३
# No token in emb. hindi ▁श्लेष्मा
# No token in emb. hindi ०९
# No token in emb. hindi (१०००
# 2642
# 2643
# 2644
# 2645
# 2646
# 2647
# 2648
# 2649
# 2650
# 2651
# 2652
# No token in emb. hindi ▁छोड़
# 2653
# No token in emb. hindi |
# 2654
# 2655
# 2656
# 2657
# 2658
# No token in emb. hindi ▁साधक
# 2659
# 2660
# 2661
# 2662
# 2663
# 2664
# 2665
# 2666
# 2667
# 2668
# No token in emb. hindi ▁छोड़
# 2669
# 2670
# 2671
# 2672
# 2673
# No token in emb. hindi ▁जोड़
# 2674
# 2675
# 2676
# 2677
# 2678
# 2679
# 2680
# 2681
# No token in emb. hindi ▁लड़के
# No token in emb. hindi ▁लड़के
# 2682
# No token in emb. hindi ▁लड़कों
# 2683
# No token in emb. hindi ▁तोड़ने
# 2684
# No token in emb. hindi १८३४
# No token in emb. hindi |
# 2685
# 2686
# 2687
# 2688
# 2689
# 2690
# 2691
# 2692
# 2693
# 2694
# No token in emb. hindi मिट्टी
# No token in emb. hindi ▁ऊष्म
# No token in emb. hindi ▁अवशोषण
# No token in emb. hindi ▁ऊष्म
# No token in emb. hindi ▁अवशोषण
# 2695
# 2696
# 2697
# No token in emb. hindi ▁बड़ा
# No token in emb. hindi ▁अतिरिक्
# 2698
# 2699
# 2700
# 2701
# 2702
# 2703
# 2704
# 2705
# 2706
# 2707
# No token in emb. hindi |
# 2708
# 2709
# 2710
# 2711
# 2712
# 2713
# 2714
# 2715
# 2716
# 2717
# 2718
# No token in emb. hindi जेरी
# 2719
# 2720
# 2721
# 2722
# 2723
# 2724
# 2725
# No token in emb. hindi ▁गड़बड़
# 2726
# 2727
# 2728
# No token in emb. hindi ▁अफ़्रीका
# No token in emb. hindi ▁ज़िक्र
# 2729
# 2730
# No token in emb. hindi ▁म्यूज़ियम
# 2731
# 2732
# 2733
# 2734
# 2735
# No token in emb. hindi ▁बड़े
# 2736
# 2737
# 2738
# 2739
# 2740
# 2741
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 2742
# 2743
# 2744
# 2745
# 2746
# 2747
# 2748
# 2749
# No token in emb. hindi ▁जीनों
# 2750
# 2751
# 2752
# No token in emb. hindi ▁वज्र
# 2753
# No token in emb. hindi |
# No token in emb. hindi |
# 2754
# No token in emb. hindi ▁लड़का
# 2755
# 2756
# No token in emb. hindi ▁ज़ी
# 2757
# 2758
# No token in emb. hindi ▁ज़ोर
# 2759
# 2760
# 2761
# 2762
# 2763
# No token in emb. hindi ▁थोड़ा
# 2764
# 2765
# No token in emb. hindi |
# 2766
# No token in emb. hindi ▁मकाउ
# 2767
# 2768
# 2769
# No token in emb. hindi ▁बैंकाक
# 2770
# No token in emb. hindi ▁दर्ज़
# 2771
# 2772
# No token in emb. hindi ▁सिर्फ़
# 2773
# No token in emb. hindi ▁काफ़ी
# 2774
# 2775
# No token in emb. hindi ▁सीढ़ियों
# 2776
# 2777
# No token in emb. hindi ▁बड़ा
# No token in emb. hindi ड़ा
# 2778
# 2779
# 2780
# 2781
# No token in emb. hindi ▁जुड़ने
# No token in emb. hindi ▁ज़रूरत
# 2782
# 2783
# No token in emb. hindi ▁ज़ी
# 2784
# No token in emb. hindi ▁बेड़े
# 2785
# 2786
# 2787
# No token in emb. hindi ▁औज़ार
# No token in emb. hindi ▁|
# 2788
# No token in emb. hindi ▁नाड़ी
# 2789
# 2790
# 2791
# 2792
# 2793
# No token in emb. hindi ▁जुड़े
# 2794
# No token in emb. hindi ▁लड़कियों
# 2795
# No token in emb. hindi ▁छोड़
# 2796
# 2797
# 2798
# No token in emb. hindi ▁क़ब्ज़
# 2799
# 2800
# 2801
# 2802
# 2803
# No token in emb. hindi ▁थोड़ी
# 2804
# 2805
# No token in emb. hindi ▁यक़ीन
# 2806
# No token in emb. hindi ▁चीज़ों
# 2807
# 2808
# 2809
# 2810
# 2811
# 2812
# No token in emb. hindi ▁जुड़ने
# 2813
# 2814
# 2815
# No token in emb. hindi फ़ल
# No token in emb. hindi फ़ल
# 2816
# 2817
# No token in emb. hindi ▁पहाड़ों
# 2818
# 2819
# No token in emb. hindi ▁फ़र्क
# No token in emb. hindi ▁पड़ता
# No token in emb. hindi िट्ज़
# 2820
# 2821
# 2822
# 2823
# 2824
# 2825
# 2826
# 2827
# No token in emb. hindi ▁बढ़
# 2828
# No token in emb. hindi ऑस्ट्रेलिया
# No token in emb. hindi |
# 2829
# No token in emb. hindi ▁ख़ुद
# No token in emb. hindi ▁पढ़
# 2830
# 2831
# No token in emb. hindi |
# 2832
# 2833
# 2834
# 2835
# No token in emb. hindi ▁रिकॉर्ड्स
# No token in emb. hindi ▁रिकॉर्ड्स
# 2836
# No token in emb. hindi ▁|
# 2837
# 2838
# 2839
# No token in emb. hindi |
# No token in emb. hindi बस्स
# No token in emb. hindi |
# No token in emb. hindi |
# 2840
# 2841
# No token in emb. hindi ▁शशि
# No token in emb. hindi च्छिक
# 2842
# 2843
# No token in emb. hindi ▁कैलिफ़ोर्निया
# No token in emb. hindi ▁बढ़ा
# No token in emb. hindi ▁नज़दीक
# No token in emb. hindi ड़ी
# 2844
# No token in emb. hindi ▁फ़
# No token in emb. hindi फ़ू
# 2845
# 2846
# 2847
# 2848
# 2849
# 2850
# 2851
# 2852
# 2853
# 2854
# 2855
# No token in emb. hindi ▁वस्तुत
# No token in emb. hindi ▁फ़िर
# 2856
# No token in emb. hindi |
# 2857
# 2858
# 2859
# No token in emb. hindi ▁लड़की
# No token in emb. hindi ▁अंग्रेज़ी
# 2860
# 2861
# No token in emb. hindi |
# 2862
# 2863
# No token in emb. hindi फ़
# 2864
# 2865
# 2866
# 2867
# 2868
# No token in emb. hindi ▁ज़रूरत
# No token in emb. hindi ▁ज़रूरत
# No token in emb. hindi ▁मुफ़्त
# 2869
# 2870
# 2871
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# 2878
# No token in emb. hindi ▁पड़े
# 2879
# 2880
# 2881
# No token in emb. hindi ▁पड़ाव
# 2882
# 2883
# 2884
# 2885
# 2886
# 2887
# 2888
# 2889
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 2896
# 2897
# 2898
# 2899
# 2900
# 2901
# 2902
# 2903
# No token in emb. hindi ▁आवाज़
# 2904
# No token in emb. hindi ▁|
# 2905
# 2906
# 2907
# 2908
# 2909
# 2910
# 2911
# No token in emb. hindi ▁|
# 2912
# 2913
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# 2920
# 2921
# 2922
# No token in emb. hindi ▁अनुपालन
# No token in emb. hindi |
# 2923
# 2924
# No token in emb. hindi ▁ज़रूरत
# No token in emb. hindi ▁चीज़
# 2925
# No token in emb. hindi ख़राब
# 2926
# 2927
# 2928
# 2929
# 2930
# No token in emb. hindi ड़
# 2931
# 2932
# No token in emb. hindi ▁फ़ोन
# 2933
# 2934
# 2935
# 2936
# 2937
# 2938
# 2939
# 2940
# 2941
# No token in emb. hindi ▁बड़
# 2942
# 2943
# 2944
# No token in emb. hindi ▁ज़िंदगी
# No token in emb. hindi ▁चीज़
# No token in emb. hindi ▁तोड़
# No token in emb. hindi ▁ज़िंदगी
# 2945
# 2946
# 2947
# 2948
# 2949
# 2950
# 2951
# 2952
# 2953
# 2954
# 2955
# No token in emb. hindi ▁प्रोफ़ेसर
# 2956
# 2957
# 2958
# 2959
# 2960
# 2961
# No token in emb. hindi ▁बड़ा
# 2962
# No token in emb. hindi थिर
# 2963
# 2964
# 2965
# 2966
# 2967
# No token in emb. hindi ▁रोज़ा
# 2968
# 2969
# 2970
# 2971
# 2972
# 2973
# 2974
# No token in emb. hindi ▁नाज़ुक
# 2975
# 2976
# No token in emb. hindi ▁आंकड़े
# 2977
# 2978
# 2979
# 2980
# No token in emb. hindi ▁गुज़र
# 2981
# No token in emb. hindi ाइज्ड
# 2982
# 2983
# 2984
# 2985
# 2986
# 2987
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# 2995
# 2996
# 2997
# 2998
# No token in emb. hindi ▁धर्मोपदेश
# 2999
# 3000
# 3001
# 3002
# 3003
# 3004
# 3005
# 3006
# 3007
# No token in emb. hindi ▁खड़ा
# 3008
# 3009
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# No token in emb. hindi ▁इंतज़ा
# 3016
# 3017
# 3018
# 3019
# No token in emb. hindi |
# 3020
# 3021
# No token in emb. hindi ▁1938
# 3022
# No token in emb. hindi ▁छोड़
# 3023
# 3024
# 3025
# No token in emb. hindi ▁ज़रूरत
# 3026
# 3027
# No token in emb. hindi ▁बड़ा
# 3028
# 3029
# No token in emb. hindi ▁बर्फ़
# No token in emb. hindi ▁|
# 3030
# No token in emb. hindi |
# 3031
# 3032
# 3033
# 3034
# No token in emb. hindi ▁फ़र्क
# 3035
# 3036
# 3037
# No token in emb. hindi ▁बड़ा
# No token in emb. hindi |
# 3038
# 3039
# No token in emb. hindi ▁पकड़ने
# 3040
# 3041
# 3042
# No token in emb. hindi ▁फ़ाइल
# No token in emb. hindi ▁ज़रूरत
# 3043
# No token in emb. hindi ज़रूरी
# 3044
# 3045
# 3046
# 3047
# 3048
# No token in emb. hindi ▁कमज़ोर
# 3049
# No token in emb. hindi ▁थोड़ी
# 3050
# No token in emb. hindi ▁फ़
# 3051
# 3052
# 3053
# 3054
# 3055
# 3056
# 3057
# 3058
# 3059
# 3060
# 3061
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# 3069
# No token in emb. hindi ▁दाढ़ी
# No token in emb. hindi क्लोज़
# 3070
# 3071
# 3072
# 3073
# 3074
# 3075
# 3076
# No token in emb. hindi क्षत्र
# 3077
# 3078
# 3079
# 3080
# No token in emb. hindi ▁बड़े
# 3081
# No token in emb. hindi ▁कड़ी
# 3082
# 3083
# 3084
# 3085
# 3086
# 3087
# 3088
# No token in emb. hindi |
# No token in emb. hindi |
# 3089
# 3090
# 3091
# No token in emb. hindi ▁छोड़ा
# No token in emb. hindi ▁पकड़ा
# 3092
# 3093
# 3094
# No token in emb. hindi ▁छोड़कर
# 3095
# No token in emb. hindi ▁पीढ़ी
# 3096
# No token in emb. hindi ▁चीज़ों
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# No token in emb. hindi ▁ख़ुद
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# No token in emb. hindi ▁ज़्यादा
# No token in emb. hindi ड़
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# No token in emb. hindi ▁छोड़
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# No token in emb. hindi ▁लड़कियों
# 3130
# 3131
# No token in emb. hindi ▁पड़ेगी
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# No token in emb. hindi ▁टुकड़ा
# 3139
# 3140
# 3141
# 3142
# 3143
# 3144
# No token in emb. hindi ▁थकावट
# 3145
# 3146
# 3147
# No token in emb. hindi ▁बड़ी
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# No token in emb. hindi ▁इन्फ़
# 3159
# No token in emb. hindi ▁बड़ी
# 3160
# 3161
# 3162
# 3163
# No token in emb. hindi ▁फ़
# 3164
# 3165
# 3166
# 3167
# No token in emb. hindi ज़ा
# 3168
# No token in emb. hindi ज़
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# No token in emb. hindi ागम
# No token in emb. hindi ▁सिकुड़
# 3176
# 3177
# 3178
# 3179
# No token in emb. hindi फ़ू
# 3180
# 3181
# 3182
# No token in emb. hindi ▁|
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# No token in emb. hindi ▁काफ़ी
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# No token in emb. hindi ▁बढ़
# 3207
# 3208
# 3209
# No token in emb. hindi |
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# No token in emb. hindi ▁|
# 3219
# 3220
# 3221
# No token in emb. hindi ▁बढ़
# 3222
# No token in emb. hindi ज़
# No token in emb. hindi ▁ज़िन्दगी
# 3223
# No token in emb. hindi ▁न्यायमूर्ति
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# No token in emb. hindi ्ज़
# 3241
# 3242
# 3243
# 3244
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 3245
# 3246
# 3247
# 3248
# No token in emb. hindi ▁तोड़ने
# 3249
# 3250
# No token in emb. hindi ▁बड़ी
# 3251
# 3252
# No token in emb. hindi ▁हज़ारों
# No token in emb. hindi ▁सैकड़ों
# 3253
# 3254
# 3255
# 3256
# No token in emb. hindi ▁चीज़ों
# 3257
# 3258
# 3259
# No token in emb. hindi ▁ज़मीन
# No token in emb. hindi फ़ल
# 3260
# 3261
# 3262
# 3263
# 3264
# No token in emb. hindi ▁पीड़ित
# 3265
# 3266
# 3267
# No token in emb. hindi ▁|
# 3268
# No token in emb. hindi ▁सफ़ाई
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# No token in emb. hindi ,700
# 3275
# 3276
# 3277
# No token in emb. hindi ▁बिज़नेस
# 3278
# 3279
# 3280
# 3281
# No token in emb. hindi संगणक
# No token in emb. hindi ▁जोड़ने
# No token in emb. hindi ▁|
# 3282
# 3283
# 3284
# 3285
# 3286
# No token in emb. hindi ▁पढ़ना
# No token in emb. hindi ▁पढ़ने
# No token in emb. hindi ▁वृत्तांत
# 3287
# No token in emb. hindi ▁जुड़े
# No token in emb. hindi í
# 3288
# 3289
# 3290
# No token in emb. hindi ▁|
# 3291
# No token in emb. hindi ▁चढ़ा
# 3292
# 3293
# No token in emb. hindi ▁लड़का
# 3294
# 3295
# No token in emb. hindi ▁बाग़
# 3296
# 3297
# 3298
# No token in emb. hindi ▁लड़की
# 3299
# No token in emb. hindi ▁फ़ोन
# 3300
# 3301
# 3302
# 3303
# No token in emb. hindi ▁बढ़ाना
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# No token in emb. hindi |
# No token in emb. hindi |
# No token in emb. hindi |
# 3310
# 3311
# 3312
# No token in emb. hindi |
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# No token in emb. hindi ▁क़
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# No token in emb. hindi ▁जुड़े
# 3326
# 3327
# 3328
# 3329
# No token in emb. hindi ▁फ़ेल
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# No token in emb. hindi ड़
# 3338
# 3339
# 3340
# 3341
# No token in emb. hindi ▁लड़ाई
# No token in emb. hindi ▁पड़ने
# No token in emb. hindi ▁बढ़ती
# 3342
# 3343
# 3344
# No token in emb. hindi ▁नज़र
# No token in emb. hindi ▁|
# 3345
# 3346
# 3347
# No token in emb. hindi ▁ज़्यादा
# 3348
# No token in emb. hindi फ़
# 3349
# No token in emb. hindi ▁लड़ना
# 3350
# No token in emb. hindi ▁छोड़
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# No token in emb. hindi ▁|
# 3360
# 3361
# 3362
# 3363
# No token in emb. hindi ▁|
# 3364
# 3365
# 3366
# 3367
# No token in emb. hindi ▁दरवाज़ा
# No token in emb. hindi ▁आवाज़
# No token in emb. hindi ▁बड़े
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# No token in emb. hindi ▁गड़बड़
# 3374
# 3375
# 3376
# 3377
# No token in emb. hindi ▁मज़ाक
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ▁बड़ी
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394
# 3395
# 3396
# No token in emb. hindi ▁फ़ोन
# 3397
# 3398
# 3399
# 3400
# No token in emb. hindi ▁फ़ैसला
# No token in emb. hindi भाड़
# 3401
# 3402
# 3403
# 3404
# No token in emb. hindi ▁छोड़
# No token in emb. hindi ▁छोड़
# 3405
# No token in emb. hindi ▁संयोजकता
# 3406
# 3407
# No token in emb. hindi ▁सिर्फ़
# 3408
# No token in emb. hindi ▁लड़की
# 3409
# 3410
# No token in emb. hindi ▁ज़िंदगी
# 3411
# 3412
# No token in emb. hindi ▁ज़मीन
# No token in emb. hindi ▁ज़मीन
# No token in emb. hindi ▁ज़मीन
# 3413
# No token in emb. hindi ▁हफ़्त
# 3414
# 3415
# 3416
# 3417
# 3418
# No token in emb. hindi ▁मोड़
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# 3426
# No token in emb. hindi जनित
# No token in emb. hindi ▁हेपाटाइटिस
# 3427
# No token in emb. hindi ▁|
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# No token in emb. hindi ▁गज़
# No token in emb. hindi ▁गज़
# No token in emb. hindi ▁गज़
# 3435
# No token in emb. hindi ▁लड़की
# 3436
# No token in emb. hindi ▁पेड़
# 3437
# 3438
# 3439
# 3440
# No token in emb. hindi सब्ज़
# No token in emb. hindi ड़ा
# 3441
# 3442
# 3443
# 3444
# No token in emb. hindi ▁फ़िर
# 3445
# 3446
# No token in emb. hindi ▁पकड़ा
# 3447
# 3448
# No token in emb. hindi ▁छोड़
# 3449
# 3450
# 3451
# 3452
# No token in emb. hindi ▁तवी
# 3453
# 3454
# No token in emb. hindi ▁ज़रा
# 3455
# 3456
# 3457
# No token in emb. hindi ▁बड़े
# 3458
# No token in emb. hindi ▁छिड़
# 3459
# No token in emb. hindi ▁ढूँढ़
# 3460
# 3461
# 3462
# 3463
# 3464
# No token in emb. hindi ▁बड़े
# 3465
# 3466
# 3467
# 3468
# 3469
# No token in emb. hindi ▁मवेशियों
# 3470
# 3471
# No token in emb. hindi ▁कलि
# No token in emb. hindi ▁तूफ़ान
# No token in emb. hindi ▁तूफ़ान
# No token in emb. hindi ▁तरफ़
# No token in emb. hindi ▁बढ़
# 3472
# 3473
# No token in emb. hindi ▁आवाज़
# No token in emb. hindi ▁पड़ा
# No token in emb. hindi ▁समीक्षकों
# 3474
# 3475
# 3476
# 3477
# 3478
# No token in emb. hindi ▁|
# 3479
# 3480
# 3481
# 3482
# No token in emb. hindi ▁बूढ़ी
# 3483
# 3484
# 3485
# 3486
# 3487
# 3488
# No token in emb. hindi ▁|
# 3489
# 3490
# 3491
# No token in emb. hindi ▁फ़िर
# No token in emb. hindi ▁बहुभुज
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# No token in emb. hindi ▁प्रायद्वीप
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# No token in emb. hindi ▁जोड़े
# 3507
# 3508
# No token in emb. hindi ▁ज़रुरत
# 3509
# 3510
# 3511
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 3512
# No token in emb. hindi लीज़
# 3513
# 3514
# 3515
# No token in emb. hindi ▁ख़रीदा
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# No token in emb. hindi ▁|
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# No token in emb. hindi ▁|
# 3536
# 3537
# 3538
# 3539
# No token in emb. hindi ▁नाज़ी
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# No token in emb. hindi ▁हज़ार
# 3555
# No token in emb. hindi फ़
# 3556
# 3557
# 3558
# 3559
# No token in emb. hindi |
# 3560
# No token in emb. hindi ▁नज़दीक
# 3561
# 3562
# 3563
# 3564
# 3565
# No token in emb. hindi ▁|
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# No token in emb. hindi ▁सिज़ोफ्रेनिया
# No token in emb. hindi ज़ो
# No token in emb. hindi फ़
# No token in emb. hindi ्फ़
# 3572
# No token in emb. hindi ▁थोड़ा
# 3573
# 3574
# 3575
# 3576
# 3577
# No token in emb. hindi ▁उपन्यासकार
# No token in emb. hindi |
# 3578
# 3579
# No token in emb. hindi “
# 3580
# No token in emb. hindi ▁रोज़
# 3581
# No token in emb. hindi ▁फ़ैल
# No token in emb. hindi ▁करोड़
# No token in emb. hindi ▁ज़्यादा
# No token in emb. hindi ▁ज़बरदस्त
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# No token in emb. hindi ▁बड़ी
# 3589
# 3590
# No token in emb. hindi |
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# No token in emb. hindi ▁ज़्यादा
# 3599
# 3600
# 3601
# 3602
# No token in emb. hindi ढ़ा
# 3603
# No token in emb. hindi |
# 3604
# No token in emb. hindi ▁ऐल्
# No token in emb. hindi फ़ा
# 3605
# 3606
# No token in emb. hindi ▁कागज़
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# No token in emb. hindi लीज़
# 3618
# 3619
# No token in emb. hindi ▁गैसें
# 3620
# 3621
# 3622
# 3623
# No token in emb. hindi ▁आड़ू
# 3624
# 3625
# 3626
# No token in emb. hindi ▁अंग्रेज़ी
# 3627
# No token in emb. hindi ▁पड़ा
# No token in emb. hindi |
# 3628
# No token in emb. hindi |
# No token in emb. hindi |
# 3629
# No token in emb. hindi ▁खिलाड़ी
# No token in emb. hindi दीप्ति
# No token in emb. hindi ▁खिलाड़ी
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# No token in emb. hindi ▁प्रोफ़ेसर
# 3645
# 3646
# No token in emb. hindi ▁उड़ा
# 3647
# 3648
# 3649
# No token in emb. hindi ▁जुड़ने
# 3650
# 3651
# 3652
# 3653
# 3654
# 3655
# No token in emb. hindi ज़ा
# No token in emb. hindi |
# 3656
# 3657
# 3658
# 3659
# No token in emb. hindi ▁ख़
# 3660
# 3661
# 3662
# 3663
# 3664
# 3665
# No token in emb. hindi ▁|
# 3666
# 3667
# 3668
# No token in emb. hindi ▁चीज़
# 3669
# 3670
# 3671
# No token in emb. hindi ▁इंतज़ा
# 3672
# No token in emb. hindi |
# 3673
# 3674
# 3675
# 3676
# No token in emb. hindi ▁जोड़ा
# 3677
# 3678
# 3679
# 3680
# No token in emb. hindi ▁लड़का
# 3681
# 3682
# 3683
# 3684
# 3685
# 3686
# No token in emb. hindi ▁ग्रू
# 3687
# 3688
# 3689
# 3690
# 3691
# No token in emb. hindi ▁बढ़िया
# 3692
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# No token in emb. hindi |
# 3699
# 3700
# 3701
# 3702
# No token in emb. hindi ▁बढ़ाने
# No token in emb. hindi ▁राज़ी
# No token in emb. hindi ▁करोड़
# No token in emb. hindi |
# 3703
# No token in emb. hindi ▁चीज़
# No token in emb. hindi ▁दृष्टिकोणों
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# No token in emb. hindi ▁जहाज़
# 3711
# 3712
# 3713
# 3714
# 3715
# No token in emb. hindi ▁लड़ाई
# 3716
# 3717
# 3718
# 3719
# No token in emb. hindi ▁लड़ाई
# 3720
# 3721
# 3722
# 3723
# 3724
# 3725
# No token in emb. hindi फ़ी
# 3726
# No token in emb. hindi ▁ज़रूरत
# 3727
# 3728
# 3729
# 3730
# 3731
# 3732
# 3733
# No token in emb. hindi ▁जोड़
# No token in emb. hindi ▁|
# No token in emb. hindi ▁|
# 3734
# 3735
# No token in emb. hindi ▁|
# 3736
# 3737
# 3738
# 3739
# 3740
# No token in emb. hindi ▁चीज़ों
# 3741
# No token in emb. hindi |
# 3742
# 3743
# 3744
# 3745
# 3746
# No token in emb. hindi ▁अलंकृत
# 3747
# 3748
# 3749
# 3750
# 3751
# 3752
# 3753
# 3754
# 3755
# No token in emb. hindi ▁हड़ताल
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# 3764
# 3765
# 3766
# 3767
# 3768
# 3769
# 3770
# 3771
# 3772
# No token in emb. hindi ▁|
# 3773
# 3774
# 3775
# 3776
# 3777
# 3778
# 3779
# 3780
# 3781
# 3782
# 3783
# 3784
# No token in emb. hindi ▁बढ़
# 3785
# 3786
# 3787
# No token in emb. hindi १९७६
# No token in emb. hindi gion
# No token in emb. hindi ▁|
# No token in emb. hindi ेत
# 3788
# 3789
# No token in emb. hindi ▁कीड़े
# 3790
# 3791
# No token in emb. hindi ▁बड़ा
# 3792
# 3793
# 3794
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3801
# No token in emb. hindi ▁|
# 3802
# 3803
# 3804
# 3805
# 3806
# 3807
# 3808
# No token in emb. hindi ▁बढ़ने
# 3809
# No token in emb. hindi ▁पकड़
# 3810
# 3811
# 3812
# 3813
# 3814
# 3815
# 3816
# 3817
# 3818
# 3819
# 3820
# 3821
# 3822
# No token in emb. hindi ▁हज़ारों
# No token in emb. hindi नियोजित
# 3823
# 3824
# No token in emb. hindi ▁छोड़
# 3825
# No token in emb. hindi ▁फ़िल्म
# 3826
# 3827
# 3828
# 3829
# 3830
# 3831
# 3832
# No token in emb. hindi ▁बड़ी
# 3833
# No token in emb. hindi ▁ऐंठन
# 3834
# No token in emb. hindi |
# 3835
# No token in emb. hindi ▁थोड़ा
# 3836
# 3837
# No token in emb. hindi ▁क़
# No token in emb. hindi ़
# No token in emb. hindi ▁ताक़त
# 3838
# 3839
# 3840
# No token in emb. hindi ▁बढ़िया
# 3841
# 3842
# 3843
# 3844
# No token in emb. hindi ▁फ़ोन
# 3845
# 3846
# 3847
# 3848
# No token in emb. hindi ▁पढ़े
# 3849
# 3850
# 3851
# 3852
# 3853
# 3854
# No token in emb. hindi ▁बड़े
# 3855
# No token in emb. hindi ▁आवाज़
# 3856
# 3857
# No token in emb. hindi ▁गुज़र
# 3858
# 3859
# 3860
# 3861
# 3862
# 3863
# No token in emb. hindi फ़
# 3864
# 3865
# 3866
# 3867
# No token in emb. hindi ▁कीड़े
# 3868
# 3869
# 3870
# No token in emb. hindi ▁बढ़ा
# 3871
# No token in emb. hindi |
# 3872
# 3873
# 3874
# 3875
# 3876
# 3877
# 3878
# 3879
# 3880
# No token in emb. hindi ▁आज़ाद
# No token in emb. hindi ▁आज़ादी
# 3881
# 3882
# 3883
# No token in emb. hindi |
# No token in emb. hindi |
# 3884
# No token in emb. hindi ▁दृढ़ता
# 3885
# No token in emb. hindi फ़िलिप
# 3886
# No token in emb. hindi ढ़ा
# 3887
# 3888
# No token in emb. hindi |
# 3889
# 3890
# 3891
# 3892
# No token in emb. hindi ▁मेज़बान
# 3893
# No token in emb. hindi ज़ार
# No token in emb. hindi ▁पड़ेगा
# 3894
# 3895
# 3896
# 3897
# No token in emb. hindi ▁फ़िर
# 3898
# 3899
# No token in emb. hindi ज़ा
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# 3908
# 3909
# 3910
# 3911
# No token in emb. hindi ▁ज़्यादा
# 3912
# No token in emb. hindi ▁छोड़
# 3913
# No token in emb. hindi ▁बड़ी
# No token in emb. hindi ▁ढ़
# No token in emb. hindi ढ़
# 3914
# 3915
# 3916
# No token in emb. hindi ▁फाड़
# No token in emb. hindi ▁ज़रा
# No token in emb. hindi ▁सड़क
# 3917
# 3918
# 3919
# No token in emb. hindi |
# 3920
# 3921
# No token in emb. hindi ▁ज़रिये
# 3922
# 3923
# No token in emb. hindi ▁|
# 3924
# 3925
# 3926
# 3927
# No token in emb. hindi ▁मोड़
# 3928
# 3929
# No token in emb. hindi ▁चीज़ें
# 3930
# 3931
# 3932
# 3933
# 3934
# 3935
# No token in emb. hindi भाड़
# 3936
# 3937
# No token in emb. hindi |
# 3938
# 3939
# 3940
# 3941
# 3942
# 3943
# 3944
# 3945
# No token in emb. hindi नाड़ी
# 3946
# 3947
# 3948
# 3949
# 3950
# No token in emb. hindi ▁|
# 3951
# 3952
# No token in emb. hindi ▁उन्मत्त
# 3953
# 3954
# 3955
# 3956
# No token in emb. hindi ▁जुड़ी
# 3957
# 3958
# 3959
# 3960
# 3961
# 3962
# No token in emb. hindi ▁|
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# 3976
# 3977
# 3978
# No token in emb. hindi ▁कॉफ़ी
# No token in emb. hindi ▁सिर्फ़
# 3979
# 3980
# 3981
# 3982
# 3983
# 3984
# 3985
# 3986
# 3987
# 3988
# 3989
# 3990
# 3991
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# No token in emb. hindi ड़ो
# No token in emb. hindi |
# 3998
# 3999
# 4000
# 4001
# 4002
# 4003
# 4004
# No token in emb. hindi ▁बड़ा
# 4005
# No token in emb. hindi ▁तंज़ानिया
# 4006
# 4007
# 4008
# 4009
# 4010
# 4011
# 4012
# 4013
# 4014
# 4015
# 4016
# No token in emb. hindi ▁दौड़
# 4017
# 4018
# 4019
# 4020
# 4021
# 4022
# 4023
# No token in emb. hindi ▁|
# 4024
# 4025
# 4026
# 4027
# 4028
# 4029
# No token in emb. hindi ▁बड़ा
# 4030
# 4031
# 4032
# 4033
# 4034
# 4035
# 4036
# 4037
# 4038
# No token in emb. hindi ▁मज़बूत
# 4039
# 4040
# 4041
# 4042
# 4043
# 4044
# No token in emb. hindi ▁खोपड़ी
# 4045
# 4046
# 4047
# 4048
# 4049
# 4050
# 4051
# 4052
# 4053
# 4054
# No token in emb. hindi ▁छोड़
# 4055
# 4056
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ▁लड़कों
# 4057
# No token in emb. hindi ▁ज़िंदा
# 4058
# No token in emb. hindi ▁बढ़
# No token in emb. hindi |
# 4059
# 4060
# 4061
# 4062
# No token in emb. hindi ▁ख़
# 4063
# 4064
# 4065
# 4066
# 4067
# 4068
# 4069
# 4070
# 4071
# 4072
# 4073
# 4074
# No token in emb. hindi ▁ग़रीब
# 4075
# No token in emb. hindi ज़ार
# 4076
# 4077
# 4078
# 4079
# 4080
# No token in emb. hindi दुःख
# 4081
# No token in emb. hindi |
# 4082
# 4083
# 4084
# 4085
# 4086
# 4087
# 4088
# 4089
# No token in emb. hindi ▁सीढ़ियाँ
# No token in emb. hindi ▁चढ़ने
# No token in emb. hindi ▁ज़मीन
# 4090
# No token in emb. hindi ▁ढूँढ़
# No token in emb. hindi ड़ा
# 4091
# 4092
# 4093
# 4094
# 4095
# 4096
# 4097
# 4098
# No token in emb. hindi ▁बड़े
# No token in emb. hindi ▁बड़ी
# 4099
# 4100
# 4101
# 4102
# 4103
# 4104
# 4105
# 4106
# No token in emb. hindi |
# 4107
# 4108
# 4109
# 4110
# No token in emb. hindi ▁रगड़
# 4111
# 4112
# 4113
# 4114
# 4115
# 4116
# No token in emb. hindi ▁बढ़ने
# No token in emb. hindi ▁ज़रूरत
# 4117
# No token in emb. hindi ▁ख़िलाफ़
# 4118
# 4119
# No token in emb. hindi ▁जोड़ने
# No token in emb. hindi ▁मौक़ा
# 4120
# 4121
# No token in emb. hindi ज़ा
# No token in emb. hindi ▁खिड़की
# 4122
# 4123
# 4124
# 4125
# 4126
# No token in emb. hindi उपयोग
# 4127
# 4128
# No token in emb. hindi |
# No token in emb. hindi |
# 4129
# 4130
# No token in emb. hindi ▁लड़ाई
# 4131
# 4132
# 4133
# 4134
# 4135
# No token in emb. hindi ▁ज़रूरत
# 4136
# 4137
# 4138
# 4139
# 4140
# 4141
# 4142
# 4143
# No token in emb. hindi ▁इज़्ज़त
# 4144
# 4145
# 4146
# 4147
# No token in emb. hindi ▁आवाज़
# No token in emb. hindi ▁बढ़ना
# 4148
# 4149
# No token in emb. hindi ▁बढ़िया
# No token in emb. hindi ▁फाड़
# 4150
# 4151
# 4152
# 4153
# 4154
# 4155
# No token in emb. hindi ज़रूरी
# 4156
# 4157
# 4158
# 4159
# No token in emb. hindi ▁पछाड़
# 4160
# 4161
# 4162
# 4163
# 4164
# 4165
# 4166
# 4167
# No token in emb. hindi ▁लड़ाकू
# 4168
# No token in emb. hindi ▁ज़रूर
# 4169
# 4170
# 4171
# 4172
# No token in emb. hindi ▁छोड़
# 4173
# No token in emb. hindi ▁आवाज़
# No token in emb. hindi ▁रोज़
# 4174
# No token in emb. hindi ▁पीढ़ियों
# 4175
# No token in emb. hindi ▁|
# 4176
# 4177
# No token in emb. hindi ▁जड़
# 4178
# No token in emb. hindi ▁|
# 4179
# No token in emb. hindi ेज़
# No token in emb. hindi ▁फ़िन
# 4180
# 4181
# 4182
# 4183
# No token in emb. hindi |
# 4184
# 4185
# 4186
# 4187
# No token in emb. hindi ▁लड़की
# 4188
# 4189
# No token in emb. hindi ▁रोज़
# 4190
# 4191
# 4192
# 4193
# 4194
# 4195
# No token in emb. hindi ▁ज़
# 4196
# 4197
# 4198
# 4199
# 4200
# 4201
# 4202
# 4203
# 4204
# No token in emb. hindi ▁मज़बूत
# No token in emb. hindi ▁पकड़
# 4205
# 4206
# 4207
# 4208
# 4209
# 4210
# 4211
# 4212
# 4213
# 4214
# 4215
# 4216
# 4217
# No token in emb. hindi ▁हज़ारों
# 4218
# 4219
# 4220
# No token in emb. hindi ▁बढ़ाते
# 4221
# 4222
# No token in emb. hindi ▁थोड़ा
# 4223
# 4224
# 4225
# 4226
# 4227
# 4228
# 4229
# 4230
# No token in emb. hindi ▁जोड़ा
# 4231
# 4232
# 4233
# 4234
# 4235
# No token in emb. hindi ▁अख़बार
# No token in emb. hindi ▁अंदाज़
# 4236
# 4237
# No token in emb. hindi ▁लड़के
# 4238
# 4239
# 4240
# 4241
# 4242
# No token in emb. hindi ▁|
# 4243
# 4244
# No token in emb. hindi ▁पकड़
# 4245
# 4246
# 4247
# 4248
# 4249
# No token in emb. hindi ▁नज़र
# 4250
# 4251
# 4252
# 4253
# 4254
# 4255
# 4256
# 4257
# 4258
# 4259
# 4260
# 4261
# 4262
# 4263
# 4264
# 4265
# 4266
# 4267
# No token in emb. hindi ▁कागज़
# No token in emb. hindi ▁पड़ा
# No token in emb. hindi ▁टुकड़ों
# No token in emb. hindi राज़
# 4268
# 4269
# 4270
# 4271
# 4272
# 4273
# 4274
# 4275
# 4276
# 4277
# 4278
# 4279
# 4280
# 4281
# No token in emb. hindi फ़ॉर्म
# No token in emb. hindi ▁खड़े
# 4282
# 4283
# 4284
# 4285
# No token in emb. hindi ▁इज़
# 4286
# No token in emb. hindi ज़र
# 4287
# 4288
# 4289
# 4290
# 4291
# 4292
# 4293
# 4294
# 4295
# 4296
# 4297
# No token in emb. hindi ▁लड़ाई
# 4298
# 4299
# No token in emb. hindi ▁बढ़
# 4300
# 4301
# No token in emb. hindi ▁सिर्फ़
# 4302
# 4303
# 4304
# 4305
# 4306
# 4307
# 4308
# 4309
# 4310
# No token in emb. hindi ▁बाड़
# 4311
# 4312
# 4313
# No token in emb. hindi ▁लड़
# 4314
# 4315
# No token in emb. hindi ▁ढूँढ़
# 4316
# No token in emb. hindi |
# 4317
# 4318
# 4319
# 4320
# 4321
# 4322
# 4323
# 4324
# No token in emb. hindi ▁ज़मीन
# No token in emb. hindi ड़ियाँ
# No token in emb. hindi ▁चढ़
# 4325
# No token in emb. hindi ▁ख़
# No token in emb. hindi ▁ख़
# 4326
# 4327
# 4328
# 4329
# 4330
# No token in emb. hindi |
# 4331
# 4332
# 4333
# 4334
# 4335
# 4336
# 4337
# 4338
# 4339
# 4340
# No token in emb. hindi ▁बढ़ते
# 4341
# No token in emb. hindi |
# 4342
# 4343
# 4344
# 4345
# 4346
# 4347
# 4348
# 4349
# No token in emb. hindi ▁सिर्फ़
# 4350
# No token in emb. hindi लसीडी
# 4351
# 4352
# No token in emb. hindi |
# 4353
# No token in emb. hindi ▁काफ़ी
# 4354
# 4355
# No token in emb. hindi ▁बढ़
# 4356
# 4357
# No token in emb. hindi ▁|
# 4358
# 4359
# 4360
# 4361
# No token in emb. hindi ▁फ़ीड
# 4362
# 4363
# 4364
# No token in emb. hindi ▁बढ़िया
# 4365
# No token in emb. hindi ▁निम
# 4366
# 4367
# 4368
# 4369
# 4370
# 4371
# 4372
# 4373
# 4374
# 4375
# 4376
# 4377
# 4378
# 4379
# No token in emb. hindi |
# 4380
# 4381
# No token in emb. hindi ▁साफ़
# 4382
# 4383
# 4384
# 4385
# 4386
# 4387
# 4388
# 4389
# 4390
# 4391
# 4392
# 4393
# 4394
# 4395
# 4396
# 4397
# No token in emb. hindi ▁पढ़ने
# 4398
# 4399
# 4400
# 4401
# 4402
# 4403
# 4404
# 4405
# 4406
# 4407
# 4408
# 4409
# 4410
# 4411
# No token in emb. hindi ज़ी
# 4412
# 4413
# 4414
# 4415
# 4416
# 4417
# 4418
# No token in emb. hindi ▁ख़त्म
# 4419
# 4420
# 4421
# 4422
# 4423
# 4424
# 4425
# No token in emb. hindi ▁जामुन
# No token in emb. hindi ▁सज़ा
# 4426
# 4427
# No token in emb. hindi ▁वक़्त
# No token in emb. hindi |
# 4428
# 4429
# 4430
# 4431
# 4432
# No token in emb. hindi ▁झगड़
# No token in emb. hindi |
# 4433
# No token in emb. hindi ▁झगड़ा
# 4434
# No token in emb. hindi ▁लड़ने
# 4435
# 4436
# 4437
# No token in emb. hindi ▁कागज़
# No token in emb. hindi ▁ज़िन्दगी
# 4438
# 4439
# 4440
# 4441
# 4442
# 4443
# No token in emb. hindi ▁घोड़ों
# 4444
# No token in emb. hindi ▁पड़े
# 4445
# No token in emb. hindi फ़
# 4446
# 4447
# 4448
# 4449
# 4450
# No token in emb. hindi ▁बढ़िया
# 4451
# 4452
# 4453
# 4454
# 4455
# No token in emb. hindi ▁क़ीमत
# 4456
# No token in emb. hindi ▁कीड़े
# 4457
# 4458
# No token in emb. hindi ▁जुड़ा
# 4459
# No token in emb. hindi ▁थोड़ा
# 4460
# 4461
# 4462
# 4463
# 4464
# 4465
# 4466
# No token in emb. hindi ▁खड़े
# 4467
# 4468
# 4469
# 4470
# 4471
# No token in emb. hindi ▁जोड़
# No token in emb. hindi असंतृप्त
# No token in emb. hindi ▁सैकड़ों
# No token in emb. hindi ▁|
# 4472
# No token in emb. hindi ▁लड़का
# No token in emb. hindi ▁रबड़
# 4473
# 4474
# No token in emb. hindi |
# 4475
# 4476
# 4477
# No token in emb. hindi ▁|
# 4478
# 4479
# 4480
# 4481
# No token in emb. hindi वाड़ा
# 4482
# 4483
# 4484
# 4485
# No token in emb. hindi ▁प्रांतस्था
# 4486
# 4487
# 4488
# 4489
# 4490
# 4491
# 4492
# No token in emb. hindi ▁जुड़
# 4493
# No token in emb. hindi ▁आज़ाद
# 4494
# 4495
# 4496
# 4497
# 4498
# 4499
# No token in emb. hindi ▁ख़ुद
# No token in emb. hindi ▁ग़लत
# 4500
# 4501
# 4502
# 4503
# 4504
# 4505
# 4506
# No token in emb. hindi ▁पकड़ने
# 4507
# 4508
# 4509
# 4510
# 4511
# 4512
# 4513
# No token in emb. hindi ▁दस्तावेज़
# 4514
# 4515
# 4516
# 4517
# 4518
# No token in emb. hindi |
# 4519
# 4520
# No token in emb. hindi ड़
# 4521
# 4522
# 4523
# 4524
# 4525
# 4526
# No token in emb. hindi ▁सिर्फ़
# No token in emb. hindi ▁फ़िर
# 4527
# 4528
# 4529
# 4530
# No token in emb. hindi ज़
# 4531
# 4532
# 4533
# 4534
# 4535
# 4536
# 4537
# No token in emb. hindi ▁छोड़ना
# 4538
# No token in emb. hindi ़
# No token in emb. hindi ▁बढ़
# 4539
# 4540
# 4541
# No token in emb. hindi ▁Cho
# 4542
# 4543
# 4544
# 4545
# 4546
# No token in emb. hindi ▁चीज़ें
# No token in emb. hindi ▁|
# No token in emb. hindi ▁ज़रा
# No token in emb. hindi ▁|
# 4547
# 4548
# No token in emb. hindi ▁ख़ुद
# 4549
# No token in emb. hindi |
# 4550
# 4551
# 4552
# No token in emb. hindi ▁पड़ता
# 4553
# No token in emb. hindi ▁बढ़ावा
# 4554
# 4555
# 4556
# 4557
# 4558
# 4559
# No token in emb. hindi ▁ज़रूरत
# 4560
# 4561
# No token in emb. hindi |
# 4562
# No token in emb. hindi ▁थोड़ा
# 4563
# 4564
# 4565
# 4566
# 4567
# 4568
# 4569
# 4570
# 4571
# No token in emb. hindi ▁लार्ज
# 4572
# No token in emb. hindi ▁बड़ी
# No token in emb. hindi ▁ज़्यादा
# No token in emb. hindi ▁ज़्यादा
# 4573
# 4574
# 4575
# 4576
# 4577
# 4578
# 4579
# 4580
# 4581
# 4582
# 4583
# No token in emb. hindi ▁निषेच
# 4584
# 4585
# 4586
# 4587
# No token in emb. hindi ▁|
# 4588
# 4589
# 4590
# 4591
# 4592
# No token in emb. hindi ▁बड़ी
# No token in emb. hindi ▁|
# 4593
# 4594
# 4595
# 4596
# No token in emb. hindi ▁फ़ोन
# No token in emb. hindi ▁बाण
# 4597
# No token in emb. hindi ▁पकड़
# 4598
# 4599
# 4600
# 4601
# No token in emb. hindi ▁लड़ाई
# 4602
# 4603
# 4604
# 4605
# 4606
# No token in emb. hindi ▁छोड़
# 4607
# 4608
# 4609
# 4610
# No token in emb. hindi ड़ियाँ
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# No token in emb. hindi |
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# No token in emb. hindi ▁बड़ा
# 4628
# No token in emb. hindi ▁|
# 4629
# 4630
# No token in emb. hindi ▁नाराज़
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# No token in emb. hindi ridge
# No token in emb. hindi ▁चढ़
# No token in emb. hindi |
# 4639
# 4640
# No token in emb. hindi ▁|
# 4641
# 4642
# 4643
# 4644
# No token in emb. hindi ▁|
# 4645
# 4646
# No token in emb. hindi ▁तोड़
# No token in emb. hindi फोड़
# 4647
# 4648
# 4649
# 4650
# No token in emb. hindi ज़
# 4651
# No token in emb. hindi ▁|
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# No token in emb. hindi |
# 4658
# 4659
# No token in emb. hindi ▁हड़ताल
# 4660
# 4661
# No token in emb. hindi निधान
# No token in emb. hindi ▁बड़ी
# 4662
# No token in emb. hindi ▁उड़ा
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# No token in emb. hindi ▁ज़ा
# No token in emb. hindi ▁चीज़
# 4669
# 4670
# 4671
# No token in emb. hindi क्विन
# No token in emb. hindi ▁|
# 4672
# 4673
# No token in emb. hindi ▁VI
# 4674
# No token in emb. hindi ▁|
# 4675
# No token in emb. hindi ▁सिर्फ़
# No token in emb. hindi ▁फ़ैला
# 4676
# 4677
# 4678
# No token in emb. hindi भाड़
# 4679
# 4680
# 4681
# No token in emb. hindi ▁रूढ़िवादी
# 4682
# 4683
# 4684
# 4685
# No token in emb. hindi ▁|
# 4686
# 4687
# 4688
# No token in emb. hindi ▁फ़्रेंच
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# No token in emb. hindi ▁चीज़
# No token in emb. hindi |
# 4695
# 4696
# 4697
# No token in emb. hindi ▁फ़र्क
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# No token in emb. hindi ▁चीज़
# No token in emb. hindi ▁नक़ल
# No token in emb. hindi ड़ो
# 4712
# No token in emb. hindi राजनीति
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# No token in emb. hindi ▁रेलगाड़ी
# 4724
# 4725
# 4726
# 4727
# No token in emb. hindi ▁अधीनस्थ
# 4728
# 4729
# 4730
# 4731
# 4732
# No token in emb. hindi |
# 4733
# 4734
# 4735
# 4736
# 4737
# 4738
# 4739
# 4740
# No token in emb. hindi ▁थोड़ा
# 4741
# 4742
# 4743
# 4744
# 4745
# 4746
# No token in emb. hindi बन्द
# No token in emb. hindi ▁|
# 4747
# 4748
# 4749
# 4750
# 4751
# 4752
# 4753
# No token in emb. hindi ▁ज़्यादा
# No token in emb. hindi ज़रूरी
# 4754
# 4755
# 4756
# No token in emb. hindi ▁जकड़
# 4757
# 4758
# 4759
# 4760
# 4761
# No token in emb. hindi ▁बढ़
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# No token in emb. hindi ▁नक़ल
# 4769
# No token in emb. hindi ▁थोड़ा
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# No token in emb. hindi ज़
# 4777
# 4778
# No token in emb. hindi फोड़
# 4779
# 4780
# 4781
# No token in emb. hindi ▁रैट
# No token in emb. hindi क्लिफ़
# No token in emb. hindi ▁बड़ा
# 4782
# 4783
# No token in emb. hindi ▁|
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# No token in emb. hindi ▁तेज़
# No token in emb. hindi |
# 4805
# 4806
# 4807
# No token in emb. hindi ▁चीज़
# 4808
# 4809
# No token in emb. hindi ▁बढ़िया
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# No token in emb. hindi ▁ट्यूनीशिया
# 4816
# No token in emb. hindi ▁ख़
# No token in emb. hindi ▁खट्टे
# No token in emb. hindi |
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# No token in emb. hindi ▁पढ़ी
# 4826
# No token in emb. hindi |
# 4827
# 4828
# 4829
# No token in emb. hindi ▁सिग्मा
# 4830
# 4831
# 4832
# 4833
# 4834
# No token in emb. hindi ▁बड़ा
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# No token in emb. hindi ▁लड़ाई
# 4851
# 4852
# No token in emb. hindi ▁पढ़े
# 4853
# 4854
# No token in emb. hindi ▁लड़कियों
# 4855
# No token in emb. hindi ▁बड़ी
# 4856
# 4857
# 4858
# 4859
# 4860
# No token in emb. hindi ▁तरफ़
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# No token in emb. hindi ▁फ़ोन
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# No token in emb. hindi |
# 4877
# No token in emb. hindi ▁पड़ा
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# No token in emb. hindi ▁काफ़ी
# 4887
# 4888
# No token in emb. hindi ▁सिर्फ़
# No token in emb. hindi ▁फ़ि
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# No token in emb. hindi ▁बढ़ते
# 4896
# No token in emb. hindi ड़
# 4897
# 4898
# 4899
# No token in emb. hindi ़
# 4900
# No token in emb. hindi ▁थोड़ा
# 4901
# No token in emb. hindi ▁टेढ़ी
# No token in emb. hindi ढ़ी
# No token in emb. hindi ▁नाड़ी
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# No token in emb. hindi ▁छोड़ना
# 4912
# 4913
# 4914
# No token in emb. hindi ▁जुड़ी
# No token in emb. hindi ▁|
# 4915
# No token in emb. hindi ▁खड़े
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# No token in emb. hindi ▁बढ़
# 4932
# No token in emb. hindi |
# 4933
# 4934
# No token in emb. hindi ▁सीढ़ियाँ
# 4935
# 4936
# 4937
# 4938
# 4939
# 4940
# 4941
# No token in emb. hindi ▁पीड़ित
# 4942
# 4943
# 4944
# 4945
# 4946
# No token in emb. hindi ▁पकड़
# 4947
# 4948
# 4949
# 4950
# No token in emb. hindi ड़ा
# 4951
# 4952
# 4953
# 4954
# 4955
# No token in emb. hindi ़
# 4956
# 4957
# No token in emb. hindi ######
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 4967
# No token in emb. hindi ▁लड़के
# No token in emb. hindi ▁लड़ने
# 4968
# 4969
# 4970
# 4971
# No token in emb. hindi फ़ी
# 4972
# 4973
# 4974
# 4975
# 4976
# No token in emb. hindi ▁छोड़
# No token in emb. hindi ▁छड़ी
# 4977
# 4978
# No token in emb. hindi ▁छोड़
# 4979
# 4980
# No token in emb. hindi |
# No token in emb. hindi |
# No token in emb. hindi |
# 4981
# 4982
# 4983
# 4984
# 4985
# No token in emb. hindi ▁नज़र
# 4986
# No token in emb. hindi |
# 4987
# 4988
# 4989
# 4990
# 4991
# 4992
# 4993
# No token in emb. hindi ▁पड़ेगा
# No token in emb. hindi ▁पड़ा
# 4994
# 4995
# 4996
# 4997
# 4998
# 4999

# %%
file2 = open("week1.txt", 'r')

# %%
ref = file2.readlines()
ref
# Out:
# ['- Will ? \n',
#  'The you you you you you you you , \n',
#  'They see come and see . \n',
#  "I think I know about of you you , and you know , of you 're , and you . of , \n",
#  'If I I , , , , , , , , , \n',
#  'In the , on the , on , \n',
#  'I was back and the and the and \n',
#  'And , , \n',
#  "I 'll have you the you before you they \n",
#  "Everything n't do n't have \n",
#  'Well , because you think you can tell you , because where we say , " where , and you , , you , , " and you , , world we you , and ? \n',
#  "In , that 's n't that we , , , we , , , we , this , , we , we , we that the we , , we this , , we the , we that the we , , the we , the , we that the \n",
#  "It 's a . \n",
#  'MAN : \n',
#  "Do n't stop that we want to go to . \n",
#  "- Who 's fucking ... \n",
#  "This 's a \n",
#  "The n't n't you \n",
#  "Here 's the world world world the world world world world the world world world world the world world world world the world world world world the world world world world , we world world world world world the world world world world world world . \n",
#  "My name 's \n",
#  "They 're coming . \n",
#  'One question you you a question question . \n',
#  'Okay , . . \n',
#  'What ? \n',
#  '( Laughter ) " , just the , " \n',
#  'First , , , , the , the \n',
#  'Thanks : Thank you . \n',
#  'Hello . \n',
#  "That 's new for new \n",
#  "This 's n't ... \n",
#  'The has become became . \n',
#  "We 'll have a a that ... ... ... ... ... ... \n",
#  'Who are ? \n',
#  'Tell me why you I mean . \n',
#  'They have have . . \n',
#  "It 's a family and children and their children in their children and their children . \n",
#  'And these are the here , and the \n',
#  '- ! \n',
#  '- Good brother , brother . \n',
#  '[ LAUGHS ] \n',
#  'This is here , you see it . . \n',
#  "And he 'll me . . . \n",
#  'I I a I I and , I my , , and . can . and and . . . \n',
#  'I mean , how ... \n',
#  'One a \n',
#  'You love love . \n',
#  'You know now . \n',
#  'Alexander , you you . . . \n',
#  'My for me . . . . \n',
#  'A . \n',
#  "No , I was gon na say I 'm \n",
#  "Well , it 's clear ! \n",
#  'In the country are . . \n',
#  'Uh . \n',
#  'What would be ? \n',
#  'I experience myself myself myself . \n',
#  "Now , he 's out . . \n",
#  "Yeah , man , man man 're gon na man \n",
#  '( Applause ) ( Applause ) ( Applause ) ( Applause ) ( about about the ) ) ( Applause ) ) \n',
#  "I 'm I I , you , you , you , of , you , , you \n",
#  "We 're the . \n",
#  '" " still has still a still . " \n',
#  'Hey , let him ! \n',
#  "And we can do n't , , that , , , , , , that , , , , we , , , \n",
#  'Mirando Mirando Mirando Mirando . \n',
#  "I 'm not saying it . \n",
#  'Why ? \n',
#  "I 'm not I , I I 'm so much . \n",
#  'Well , a man a a a \n',
#  "So I learned that I 'm going to \n",
#  '( Applause ) I about I about and about and \n',
#  "You ca n't save . \n",
#  "They 're gon na be like , they 're 're 're like , 're \n",
#  'Yeah , I , you you , a , friend of here . \n',
#  'One , first \n',
#  'Hello , , . . \n',
#  'Today . \n',
#  'My and and and and and and and . \n',
#  'They had been this how much of \n',
#  'The will be , . . \n',
#  "When he 's happy . \n",
#  'You stop you . \n',
#  "But I ca n't you it \n",
#  'I think I was been thinking ... \n',
#  'Just you just go , but of the of , that you , and \n',
#  'When we have a about these , , , we are . . . . \n',
#  'How do you know how you do all ? \n',
#  "If he just n't , , , , , , , , , , \n",
#  'He them ! \n',
#  '- ! \n',
#  'Or . \n',
#  'Just it ! \n',
#  "I do n't know n't I . . \n",
#  'Our ! ! ! \n',
#  "I 've all -- I , I all , , \n",
#  'And -- ) to of -- -- , -- from the -- from high -- ( Laughter ) for -- of -- ( Applause ) to , -- and that of the , that \n',
#  "No , you can n't , or ... ... \n",
#  "They 're money , and they 're and money and money \n",
#  "I 've I I before with , , with , \n",
#  'After the two hours after him him , after him . \n',
#  'I I I , , because I I the , and because I was , , because I , , and the , and , and , because I , and the , , and , and , and , and , and , , and the , , and , and the , and , and the , and and , and the \n',
#  "I 'll be my I ! ! ! ! \n",
#  'In a , " ago , a a a \n',
#  '- Have you ? \n',
#  "You can do , , , you 're , \n",
#  "That 's it was a \n",
#  'The dead dead . \n',
#  'I know my me from the me \n',
#  'So , I had to be the , \n',
#  'Who will make this great ? \n',
#  "In an opportunity that I think I 'm a job , and I work , it in a , \n",
#  'In you are you looking for who say , you see you the who ? \n',
#  "He did n't pay . \n",
#  '( Laughter ) ( Applause ) ( was a , \n',
#  'I was was was , \n',
#  'Not any chance . \n',
#  "She 's a woman , \n",
#  'Get away out ! \n',
#  "It 's a -- \n",
#  'I want to see it . \n',
#  'Okay , , , man . \n',
#  'Is it was that for him ? \n',
#  'Now , this is time time we have time \n',
#  "And we 're working , with other countries , we 're working with their own , and we , are with , and . \n",
#  'A the of \n',
#  'I wanted to I like and and and and , and and and and and and and and and and and and \n',
#  'And if , this , , , this , , , , , this , , , , , we , , , , to , , , , , and , , to , , because you , this , this , was , \n',
#  'You you a . \n',
#  "There 's a a -- the -- -- the -- -- -- the -- -- -- -- -- the -- -- -- -- -- -- -- the -- -- or the a -- -- -- a the -- -- -- a the -- a the that -- it \n",
#  '- Hey ! \n',
#  'I . \n',
#  'Where they do ? ? \n',
#  'Come on , \n',
#  '- In the in in in in in in the \n',
#  'And now this is a , important , , , , , , , important , , government , , and , \n',
#  'Tell . \n',
#  'Not . \n',
#  'We . \n',
#  "And it 's also , and of \n",
#  "Let 's go . let 's go . \n",
#  "And it 's a . . \n",
#  "I 'll have time from the car . \n",
#  "- Do n't let a couple ? \n",
#  "What 's of with new , with new woman with with new with new with \n",
#  "One 's a ! \n",
#  "It 's time time . \n",
#  "He 's enough to the . \n",
#  "Because in , we do n't , and of because it , and , \n",
#  'No one will be a a . \n',
#  "I mean , she 's a , she . \n",
#  "We 'll like a like , that when we on , a , , , or , , we that . like , we \n",
#  'I n\'t I n\'t you I I my n\'t you ? " ? ? ? ? \n',
#  'A to you ? \n',
#  'You okay ? \n',
#  '[ [ ] ] ] ] ] ] ] \n',
#  '( Applause ) or or a or \n',
#  'After years after her after , I will \n',
#  "Just 's just a \n",
#  "I think n't you n't you you you , you , you \n",
#  'They can see you can be , , and , and , and , and , and \n',
#  "If I love him , I 'm love him about him \n",
#  'No , \n',
#  "Let 's . . . \n",
#  '- he South South South South South South South South South South South South South South South South South South South South South South South South South South South - South South South South South South South South South South South South South South South South South South South South South South South South South South - South South South South South South South South South South South South South South South - South South South South South South South South South - South South South South South South South - South South South South South South - South South South South South - South South South South South - South South South South - South South South South - South South South South - South South South - South South South - South South South - South South South - South South South - South South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - South - being . \n',
#  'But I , , in , Europe , in Europe , so they have been able to be . \n',
#  'But I think about , " I , you , " about , ? \n',
#  'The was .. \n',
#  "You 'll talk ... \n",
#  'Let him ! \n',
#  'For , for the \n',
#  'All lives are all of life . \n',
#  '" You \'ll go ... \n',
#  'But of this actually come out of some of you , you just really think of here . \n',
#  "I just just just do n't with it , \n",
#  'All three , they , \n',
#  'The first was the and , and and and and and and and and and and the and and , and and and and and and \n',
#  'The . \n',
#  'I think I have a , , of , and , , \n',
#  'And the , of . . . . . . \n',
#  'And we , other the , in , which , we , , , and , the , , and , the , and , the , and the , and the , they , , and the \n',
#  "- What 's it ! \n",
#  "You ca n't way out a way out of this way out ! \n",
#  'I hope better . \n',
#  "Not just , but but , but n't just me , but just \n",
#  'But the us the in us \n',
#  "She 'll try tried to be . \n",
#  'Then then , , , , , and , , , , , and , , , , and , \n',
#  'In , , and the , , , , , , and , , and , , and , , and , , and the , and , and and , and and , and \n',
#  "Why 's important ? \n",
#  'In this , this was , the , of this , this was , and in , the , \n',
#  'She said , " n\'t n\'t " \n',
#  'And I will will will be I . \n',
#  "I n't have n't , the , the on , the \n",
#  'I asked me with me , " with , and I asked me asked me with me with me with me with me , " I asked . " \n',
#  "You 'll be . . \n",
#  'Now these are , these are , these are these are these people these are . \n',
#  'It is it . \n',
#  "I 've too a too . \n",
#  '( Laughter ) Yeah , right . \n',
#  'He cut him . \n',
#  'What they are ? \n',
#  "It 's that a that way that \n",
#  'I . \n',
#  "We do n't know that two the in . \n",
#  "Some 've looked , in the , , have to , \n",
#  "Everybody it it it , but it 's just but it it it it it \n",
#  'My favorite is is of favorite . \n',
#  'Hello ? \n',
#  'Just your your , \n',
#  'What ? \n',
#  'She was that I was \n',
#  'As , as , , are , the , are who as the are as the , , \n',
#  'So we should ... to some about ? \n',
#  'I know that . \n',
#  "Maybe it 's too . \n",
#  "You 'll be . . . \n",
#  'We have wrong is wrong wrong wrong . \n',
#  'And the of the in and the in and , and the , , and the , in and the , and in \n',
#  "I do n't know . \n",
#  'Right now , the ! \n',
#  'In night , the night . \n',
#  "I mean , I do n't want to , it , if I do n't believe , and , that and , and the , and , and , and \n",
#  "You 've got your . \n",
#  'If the world , or , or , , or , \n',
#  'The ! \n',
#  'And the parents the parents parents -- " child the parents parents , " child " child " n\'t n\'t child " child child " " that child " n\'t n\'t " their child child . " " \n',
#  'So , I I to , , , to , a , to , a , \n',
#  'How is ? \n',
#  '( Laughter ) I think I I because because I because because I than because of \n',
#  "That 's we . . . . . . . . . . \n",
#  'So , in way and is , and the , and and the , and and and and and and and the \n',
#  'All this time we see a see . . \n',
#  "I 'm very . \n",
#  "That 's worse . \n",
#  'Please . . \n',
#  'I think I guess . \n',
#  'So we have to these things , these things we have team of these things . \n',
#  'Who can in in ? \n',
#  'Oh , \n',
#  "I 've I here to . \n",
#  "That 's n't , 's , the 's , a 's , the 's , the 's , or the a \n",
#  '- I will be . . \n',
#  'Only only \n',
#  'By fire ! \n',
#  'Well , science science science science , and can science science , and can science science , and can science science , and can science them science , and they can use them . \n',
#  'And we can are . . . \n',
#  'So we see see are all of looking at all of looking , we see , we see , in the , of , , the , \n',
#  'gun gun . \n',
#  'Some of the even think about the of , it , it even that it possible the brain of the that \n',
#  'They they call him . \n',
#  "We 'll have , you you you you you you before you that you you \n",
#  'Come , you you come coming . \n',
#  'But , really is , the thing . \n',
#  'The . \n',
#  'Just it . \n',
#  "It was n't it else was a woman , and it was n't . \n",
#  'First first of the worst \n',
#  'One like a little bit of a . \n',
#  "I 'll do that I . . \n",
#  'He became a father became at the front of his own father as a woman and he had a shared . \n',
#  'Every we work every work and we every work and we every we and work and work \n',
#  "I 'm that I I money . \n",
#  'And then next next next next next next next next next next next next next next next next \n',
#  "I think you do n't you you , you , you , you , you , you , you , you , , you , , and you , , , you , , , \n",
#  "I was I I when I n't . . . \n",
#  '( Laughter ) Now if I have time to be if I have time ? \n',
#  'I my on my and of , and the \n',
#  "It 's a . \n",
#  '[ laughter ] ] and , \n',
#  'It it . . \n',
#  "You 're us , you \n",
#  'In , they , on -- they ! \n',
#  'Will ? \n',
#  "She 's something for to . \n",
#  'And as the of -- in -- -- \n',
#  'With . . \n',
#  'Oh , \n',
#  'From the , and we came to the , and , and the \n',
#  "One king , n't a king , n't . \n",
#  'But on and my was and \n',
#  'MAN : \n',
#  'Our are not ; is ; wrong is not ; \n',
#  "( Laughter ) And then I 'll a in the \n",
#  'Very of the . \n',
#  'Because it was a job ? \n',
#  "They 're gon na car us car . \n",
#  'So about , and , " about , and who have n\'t have the , and and , and , and and , " , about , and and \n',
#  "I 'm looking at my see , I 'm looking for my . \n",
#  'Your dad ! \n',
#  'Keep off out of my son ! \n',
#  'Help you ! \n',
#  'If I was in the and in and and and and \n',
#  'Because we have because about because and because , and because you , and because you , and because you , and , and you , and and , and and you , and , and and , and about and , and \n',
#  'And I think we believe a believe , we can a a a \n',
#  'The , who have an who have is , the , , the \n',
#  'I me . . \n',
#  'Last year ... \n',
#  'You know . \n',
#  "That 's good and all right , and , and the good \n",
#  'Tell me . \n',
#  'But I believe I believe I believe . \n',
#  'Now there looks like the little of \n',
#  'He took his back ! \n',
#  'Give us something . \n',
#  'In the is the of a is , a team the the a , of a \n',
#  "( Laughter ) ( Laughter ) I 'm talking about about . \n",
#  'You know you you of \n',
#  "But I I college college college college college college college college , because I 'm n't college that \n",
#  "And this 's a that this this is that that a , that I that this a that , \n",
#  "And if you know you you a other life , you know , you 're a you life , of a you life , life we life , and \n",
#  "( Laughter ) And of the two , they 're going like , and they they and and , and they \n",
#  'God , how this \n',
#  'A like a work a \n',
#  'We have ta have behind the . \n',
#  '- . \n',
#  '( Laughter ) ( Applause ) The we -- ( Laughter ) " we ) we ) we , -- we , and the , . the . is the we \n',
#  "I do n't have it , I do n't it it . \n",
#  'We have my . . . . . . . \n',
#  "You see , you 're getting . \n",
#  'In the , the , the the , the the the \n',
#  "And it 's not like . . \n",
#  'I was ... \n',
#  'Are you gon na be ? \n',
#  'And all . \n',
#  'Then we are these are and are , we are in and \n',
#  "- There 's n't here . . \n",
#  '- Yeah , right right . \n',
#  'A team of team team team team was that team team \n',
#  'Well , I know know that the from , \n',
#  'And the , of -- -- -- \n',
#  "I 'm asking you ! \n",
#  'In a , that , a that was a a \n',
#  '- Something ! \n',
#  'Take your passport passport passport and take it . \n',
#  'In the school they they and with , and with and . \n',
#  'The is is their their . \n',
#  'In , the of , , , of , , the , of , the , \n',
#  'We also use great of great great for great great great - new great . \n',
#  'Why are a a ? \n',
#  'Hey , wait , \n',
#  'My boss boss . \n',
#  'That was ... \n',
#  'With the woman behind the woman . \n',
#  'You heard me , you ? \n',
#  'Show , \n',
#  "If you see , you 're looking and you 're looking at . \n",
#  "There 's gon na get down there . \n",
#  "This 's a an a \n",
#  "She 's in your enemy . \n",
#  'No now now now . \n',
#  'For for 1 on the , I I , but on the \n',
#  'Uncle . \n',
#  'That \'s a big of the . . " . \n',
#  "I 'll feel you feel you feel . \n",
#  "No matter you have n't you , you me , you . \n",
#  'I told you I I I I said . \n',
#  'Not here . \n',
#  "In 's , of and the , \n",
#  'She was was was was was was was was was was was was the was , was that of in and the \n',
#  "- I think you you n't you \n",
#  'Even the American ] that no way to be so much . \n',
#  "You you see you you can you of your can you your can n't you , \n",
#  'In two , the , , two , , , , , , , , , , and the , . \n',
#  'But if the of , fast fast , they can have fast , the of \n',
#  'How how to the ? \n',
#  'We thought we use about this use language to use their language system language , they could use their own language . \n',
#  "I 've to I that to , for , , to , , , which , which , which , which , which is what I 've been done with , I 've been done to do with that . \n",
#  'I was gon na to , this \n',
#  "- You 're dead , die . \n",
#  'I : I about the , the , the on three the that three the , the , the \n',
#  'And I I I old and and and \n',
#  "Do n't look at . \n",
#  "He 'll give it . \n",
#  'Good morning . \n',
#  "If you did n't it , and if you did n't . \n",
#  'And the government government is in government is , in government , in government , and with government , the , government in and the , and , government and the , and , government in , and the \n',
#  'So you know , you know you a , and you , and . you . . \n',
#  '" When " in , " , " , " " " " " " " " " " \n',
#  'It was that way that way that way that way that way . \n',
#  "And light 's getting light . \n",
#  "But about a little thing , you , a , a , and you , , and you , and you , and n't you , and , \n",
#  '( Laughter ) ( Applause " I have ) " My favorite , " " OK . " \n',
#  "I 've my , , , , , , , and , \n",
#  'So what is ? \n',
#  "I 'm I I I you I I \n",
#  '( Laughter ) I said I said , " I said you " " \n',
#  "We were n't that us that \n",
#  "I ca n't you be . . can be . \n",
#  "He 's him ! ! \n",
#  'You got no ... \n',
#  'Okay , , , \n',
#  'Captain . \n',
#  'LB : No , you you \n',
#  "I was n't I that I old than that \n",
#  'You should be be crazy . \n',
#  'Okay , \n',
#  'I can get out on out there on out there , \n',
#  "But China 's economic growth growth than the same technology of the growth . \n",
#  '- I know . \n',
#  'I remember that I remember , and I remember , but it , and but I \n',
#  'One of dollars . \n',
#  'Who gon na take us na have gon na na us na do ? \n',
#  'In a problem , society is a society society . \n',
#  "That 's why they have to do \n",
#  'And now we can go now is a far of the \n',
#  'The was percent was . \n',
#  'I got got children . \n',
#  "Let 's try try . \n",
#  '" Let \'s " " " " " " " \n',
#  'In the , want to , in , . \n',
#  'Okay , . \n',
#  'He took a global world , a global world , a global world to the world , world world world of \n',
#  'I were that they were . with \n',
#  'What ? \n',
#  'I I I my mom , for the , and , I I , \n',
#  "What 's your mind . \n",
#  "They 're too they 're . 're \n",
#  'So how I do you ? \n',
#  'Something ? \n',
#  'Where did you ? \n',
#  "Alan , we 'll do you . . \n",
#  '- Do you it ? \n',
#  "Let 's go him ! \n",
#  "We 've to see the health , health to see . \n",
#  'You my brother . brother . \n',
#  "I 'll 'll 'll do 'll you I 'll do 'll you 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll 'll the \n",
#  'What ? \n',
#  'Do you know where you , where you , you , \n',
#  'And she can with , , , , , , , , , , , , , , , , you , , , , , , , , , , , \n',
#  'Have you ever seen the next and the , you and \n',
#  'Sometimes the great good . \n',
#  'One car with car with car . \n',
#  'They are DNA DNA DNA DNA DNA DNA DNA . \n',
#  '( Laughter ) And we are . . \n',
#  'You you you ? \n',
#  'So about , you do about it ? \n',
#  'Four ? \n',
#  '- Sorry you want . . \n',
#  'In , back here , , are coming back . \n',
#  'What do he loves it ? \n',
#  'When you see , when you got the , and . . \n',
#  'The are and . \n',
#  'Hey , let me . \n',
#  '( Applause ) But about the -- and , and , and and and and and and , and and and and and and the \n',
#  "We 're not a you a , and you . \n",
#  '- Do you have to ? \n',
#  'I want I want to go inside . \n',
#  'But the of in , this , in it , of the . \n',
#  "I 'm my \n",
#  'And in the in and in the : \n',
#  'How many ? \n',
#  'We have to \n',
#  'How do you know ? \n',
#  "If the -- that 's on the -- on \n",
#  "( Laughter ) we were n't know ) . \n",
#  'This is this way . \n',
#  'You you you this you \n',
#  'The , you you you you you you ? \n',
#  'It his face and his person and his person and \n',
#  "Why n't n't n't the that n't \n",
#  "You 've forgotten to the . \n",
#  '( : ) : Thank you ) \n',
#  'What , you you ? \n',
#  '- Tell me from the last . \n',
#  'Is ? \n',
#  'I will I to to to to this I to , , to , to , I to \n',
#  'You me ... me ... me ... \n',
#  'The next time , we \n',
#  'The . \n',
#  "You know you 're not you \n",
#  'There are a the the on the the dollars on , the are the \n',
#  'At hours , will give it . \n',
#  'You can still get married . \n',
#  "And , , n't , ? \n",
#  'These are the on who these the , on , the their , of \n',
#  "I 'm about , , I 'm , and , about , , I , that , about , and , of the , and \n",
#  "He was n't on , but but the \n",
#  'I , you , , , or , , \n',
#  'We see , , , , and , , , , , and , can , , , and , \n',
#  'We have technology . . technology . \n',
#  'And we were that that that on the \n',
#  "I 've seen you down . \n",
#  "It 's just little , who were a little who , because that your little the \n",
#  "- They 're coming back . \n",
#  'In the the and the the with the with the and \n',
#  "You do n't , you and you , and and and and and . with you , . \n",
#  'In one one one of in one one one of the one , \n',
#  'I I my as a as , " my my my as my as my as a as my \n',
#  "Yeah , but n't n't tell , \n",
#  'You my . . . \n',
#  'Seven ? \n',
#  'These will be a these on a these where on these kids have a where on these world on where on is , where will these will have a world on \n',
#  "What 's your face ? \n",
#  'Move . \n',
#  "These 's example of example . \n",
#  '[ ] ] ] the \n',
#  'My Führer is that this is that two with the a \n',
#  "There 's back back back . \n",
#  "In day she him that day he 's that that she him . . . \n",
#  'And , , , who and , , and you , \n',
#  'Do you call it ? \n',
#  '- Is them we get ? \n',
#  'Yeah ... \n',
#  'A new new friend ? \n',
#  'I do I do ? \n',
#  'My wife and children and wife . \n',
#  "I 've been able to them on the future . \n",
#  "You 'll have to tell you . \n",
#  "I 've n't I , I , n't , \n",
#  'The then , the . \n',
#  'We . . . \n',
#  'You can think ... our ... ... \n',
#  "Now , we 're that we that \n",
#  'And more . \n',
#  "We should n't \n",
#  '" I will I n\'t I . . . . \n',
#  'The most thing we ever had this . \n',
#  'The . \n',
#  'Your , all of your life , you have all of your life . of . \n',
#  'But night , the that thing they went on . \n',
#  'Well , men , men . \n',
#  'FUCKING it . \n',
#  'In the never always never , it was , the never , it was , and never \n',
#  'So if I I , , , of and , , and , , life , and , and life , and \n',
#  "You 're it . \n",
#  "I mean n't I mean in an example of the third - old language , in the language , the left of the \n",
#  'These are a new life of a of . of . \n',
#  "She 's in danger . \n",
#  'And when I I , we , , we , we , we , we , and , \n',
#  'Just better better than better . \n',
#  'When this changed when the study , when the study when we have changed when the study , when the study when the changed when the , \n',
#  'And if I can I if you , then I \n',
#  'Okay , okay ? \n',
#  "Well , n't n't have to be with , but they , 're , \n",
#  "Do n't are . \n",
#  'In my daughter ... \n',
#  "Who 's man ? \n",
#  "Do n't \n",
#  'he he sent he sent to the \n',
#  'Oh , , thinking about , you were thinking about a \n',
#  'My the American American American \n',
#  'I better better than . \n',
#  'So this is important , of in important , the important , in the of \n',
#  "Let 's try a try ! \n",
#  'Of course . \n',
#  '( Laughter ) I I I . you . \n',
#  'Let me let you . . \n',
#  'Hurry ! \n',
#  'These are ... \n',
#  'I need my . . \n',
#  'Or we we waiting ? \n',
#  '( Applause ) new new new new new . \n',
#  "In the 's the . . . . . . . . . . . \n",
#  'Sean : \n',
#  '( Laughter ) Now is a long day is a is , is of \n',
#  'They they this this their to this their , and this they , , a , , and they , , a and and , , \n',
#  'I wanted to I I . my . \n',
#  '- With that . \n',
#  'Simon it ... things things it ... things things ... \n',
#  'The , I . . . . \n',
#  'They were all they want to do . \n',
#  "Well , ... 's ... \n",
#  "You do n't trust you . \n",
#  'CA : And every every - every : this every - can a . \n',
#  'But the was had in , the , \n',
#  'One is on you . you . . \n',
#  "You know now know they 're now now . \n",
#  "I 'll , , , , , , for , , , to \n",
#  "Of course , you 're on , you 're . . . \n",
#  'What ? \n',
#  'The is ... is is still the . \n',
#  'Then I I him . . \n',
#  'In it in in in the , of in , without without that without it , without without it without be without the wrong of the . \n',
#  "I 've I I you you . \n",
#  "And , let 's have a chance to you . \n",
#  'In of many of people , who have of the many of their who have left their than their . of . of . of . of . of . of . of . \n',
#  'A wants tonight . \n',
#  'Is he out of night out night ? \n',
#  'You ! \n',
#  'Where are they ? \n',
#  '? ? \n',
#  'I had , I I , , was , , of \n',
#  "( Laughter ) ( Applause ) I 'll do this . \n",
#  "They 'll have them . \n",
#  'Just you have to , , you , , of , , you , , you , you , , \n',
#  "We 'll . \n",
#  'What are we going ? \n',
#  'Your my , my \n',
#  '- How did you ? ? \n',
#  'She . . \n',
#  "And also , , because that an because n't , , , and , , a , , and of , and . the . \n",
#  "That 's about about about it . \n",
#  "And then , , that there 's but some of , , but are , \n",
#  'What happened down there ? \n',
#  'Why would be like I mean ? \n',
#  "I both a both of for you both ' both of your . \n",
#  "( Laughter ) That 's why . \n",
#  'In , . \n',
#  'I me . . \n',
#  "She 's a a a million to he \n",
#  'And , , about , , , , , , , and , , , , the , and , , , and , , and , , and , and , the , and , of , and , , and the , and , and the , and , the , and the , and the , \n',
#  "Let 's . . \n",
#  'Stay back ! \n',
#  "And when we know , they 're , they are , they 're , , , they are , , , we are , that , \n",
#  "Do n't you or my or , or , or or , or ? \n",
#  "There 's a , there , and , and , \n",
#  "I 've got . \n",
#  'In , , about , the . \n',
#  'Can you can do you ? ? \n',
#  'What are you doing here ? \n',
#  'And two : And two : And the are different two things different things the other things are different things . \n',
#  "What 's wrong with you ? \n",
#  "This 's where that the where that where the where is where that the where that is where that ... the \n",
#  'By the most of -- -- -- as a as about -- as the most of -- as the -- as a -- -- as a -- -- as a -- as the -- as of as as a -- -- as the -- as \n',
#  'Get me out ! \n',
#  'And we family family . \n',
#  "( Laughter ) And I will have n't have this we that we this is that we this that we this that is that that , that we this . that . that . this . that . . this . . . this . . . \n",
#  "We did n't have happened with the you you you , but of in , but you , \n",
#  'In , the of the , the , the of and the , the , in the , of the , \n',
#  'For me , they are me for me . \n',
#  '[ LAUGHS ] ] \n',
#  'I I I here of here the \n',
#  "That 's . \n",
#  "We 've made to the some of the , the \n",
#  'And when you know , you know , you know , you know , you , you , you , world about , , world the you , , \n',
#  'Thanks . \n',
#  "I know I know , my I on my understand , my do I do n't understand , but they do n't know that . \n",
#  "No , I do n't you you , you can you , \n",
#  'But I think he never never , never that \n',
#  "I 'll have you you you you you you . \n",
#  "Listen , I did n't listen me . \n",
#  'What , , will . \n',
#  'The are the . \n',
#  'The three weeks in the time , three weeks ? \n',
#  'Three ! \n',
#  '- never never have never never him . \n',
#  "We are n't on , we are , we on , are we , \n",
#  'MAN : \n',
#  "And when he 'll be when you , that . \n",
#  'Get out ! \n',
#  'In their name they have a a in their their name and their their their their in their their . their . their . their . \n',
#  "I 'll get a . . \n",
#  "Do n't , of , of , ? \n",
#  'You know of sister , you have to get married . \n',
#  'So every the the , every the \n',
#  "I 've got got a \n",
#  'Look at the company of the \n',
#  'Most , for , of , \n',
#  "But we did n't just just have the , , and , , , and , , and , and , and , and , . and . \n",
#  'In in today , you share with the middle . \n',
#  'In the , and he started , and he and the , and and , and and and , and and the , and \n',
#  "- No , you 're okay . \n",
#  "If you 're , a , they , , , they , 're , , they , 're , , \n",
#  '( Laughter ) And I I I would miss them . \n',
#  'What are you ? \n',
#  "I 'm sorry . \n",
#  'What is he ? \n',
#  'Really . \n',
#  "Today n't be there 's the of , of \n",
#  '( CHATTERING ) \n',
#  '( Applause ) ) ) \n',
#  'Doug for Doug . \n',
#  'I know you I like , you , you , you , you , you \n',
#  "This 's United States for the United States . \n",
#  'What are working up of your whole ? \n',
#  "I 'll have a outside and outside of front of front . \n",
#  'I Police to the police , for the \n',
#  "Do n't be . . \n",
#  "I 've got a high , I I I about a about , , . \n",
#  '- One kind of a . \n',
#  'Oh , I about about about , \n',
#  'In the middle on the middle - American , the next few - year - on - , have done the entire \n',
#  "We 've got to get a . \n",
#  'Hey , you you ... ... ... \n',
#  'And if I have a " , a " , " " " " " " " " " " " \n',
#  'And I was a , a , \n',
#  "I 'm I . . . . . . \n",
#  "I 'm happy you . \n",
#  'And , , , , and , \n',
#  "Some things it 's . \n",
#  "I 'm home . . . . . . \n",
#  "They did n't have them , and they , , \n",
#  "- Let 'll be . . \n",
#  'If he was that a the that that the that that that would be that a the , that \n',
#  'In , , . . . . . . . . . . . . . . . . . . \n',
#  "It 's trying to call it and try \n",
#  "You do n't have me , I n't have and me I \n",
#  'In the police , the of the the percent of the of the the of the the \n',
#  'And they were they their their they on \n',
#  '( Laughter ) \n',
#  "Maybe I 've 've too for any kind of time , \n",
#  '- Can I help you ? \n',
#  'Scott . \n',
#  'I want to see Okja ... \n',
#  'Hey , \n',
#  "We 'll have that a know who have a that the that world that day that \n",
#  'What are doing ? \n',
#  'Everybody knows we know . \n',
#  "And if you see the , that of you , , that you , , that , you , , that , , that , you , , , that of , , , , that 's the , , , \n",
#  '- , . . . . \n',
#  'In . . \n',
#  "- We 'll have a the of a . \n",
#  "She 's a a \n",
#  'In in in fact , you wanted in this is , you you , you in , and you " , and you the and world the " and you " you " you " you \n',
#  "This 's a a , of a -- on a , a , or no of a a . \n",
#  'Is he good to the best ? \n',
#  "- Maybe n't n't there be . . \n",
#  'Okay . \n',
#  'In this study the were ) And of in from the of of of this in of \n',
#  '- A that . . \n',
#  'Yeah we can do . \n',
#  "And do n't you do do it ? \n",
#  'You want to be or down , or some or you \n',
#  "I 'm telling , is a country system ! \n",
#  'It was the the the the government on \n',
#  "We 're coming . \n",
#  '( Applause ) ) ) ) ) ) ) ) ( ) ) ) ) ) ) ) ) ) ) \n',
#  "I do n't have to the most of most of most of most of most of the most of most of \n",
#  "I 've n't you , you , you , you , of you , you , about , of , \n",
#  "I ca n't , \n",
#  'The the are you the you world thing you is that \n',
#  'After something hours , and hours . \n',
#  '15 seconds . \n',
#  'And then , these new new , , , new , , , these , \n',
#  '- ! \n',
#  'It was completely , completely . \n',
#  'That was that was that . . \n',
#  '♪ # # . \n',
#  'I hope with you . \n',
#  "We 're both on both . . . . . \n",
#  'If I try to try these of , and that that I try to get that the that , that these are trying to try to the that of , and , that and and , that and on the , and that , and the , and that and and the , and that and the \n',
#  '- Have anyone have a seat ? \n',
#  'And these , use , use these are , \n',
#  "And we 'll be this we , this we that this human process that human family will be in human rights . \n",
#  'The . \n',
#  'One the . \n',
#  'What can we tell about us in about us the last night ? \n',
#  '[ woman ] \n',
#  'I need you to you . \n',
#  "So you do n't you you ? you ? \n",
#  "What 's wrong with you ? \n",
#  'What ? \n',
#  'On on ! \n',
#  "Do n't call \n",
#  "But it it it was the parents the parents in the it , and n't it it , it it was , it and n't \n",
#  'Did you see some of you ? \n',
#  'This you you see you your of , you . \n',
#  "- He 's a ! ! \n",
#  'These are a number of this . \n',
#  'And it took a company , I had to get the company , and I , , a , a \n',
#  "And we can do n't be for until we can can take them for their until to their their can be in , they can , they \n",
#  'Now , only our , \n',
#  "That 's a true truth . \n",
#  "You 're lucky , because you 're lucky ... the day . \n",
#  'Where I I ? \n',
#  'Or ? \n',
#  "They 're sitting in the room with the room they 're 're . \n",
#  'How long is he ? \n',
#  'These was , and I I was , and \n',
#  'Thank you . \n',
#  'This is that red red red red , and red red is a red red . \n',
#  "But this problem n't be n't , it \n",
#  'You fucking asshole asshole . \n',
#  'Man , I started dead , two , \n',
#  "I think I can think I can do n't , \n",
#  'Scott ! \n',
#  "Yeah , I do n't \n",
#  'When they , when you , when , , \n',
#  "Do n't be n't be ? \n",
#  '- . \n',
#  'Call now now ! \n',
#  "I 've done . \n",
#  'And way way way way way way way way way way way way way way way way way way way way way way this way way is that way way way way way . \n',
#  '" The he " and . \n',
#  "I 've got to with we that a , we with we , with we that . life . own . \n",
#  "Let 's the of social problems . \n",
#  '- So . \n',
#  'In two words in two words from their words . \n',
#  '( Laughter ) The truth is true , the truth is the truth is the truth is the truth . \n',
#  "You 're gon na kill me . \n",
#  "I 'll have the the in the \n",
#  "Look this 's a \n",
#  "It 's n't us it a , a us where we have a , it a us \n",
#  '- \n',
#  'So you have , you , you , and you , , , and , , you , , \n',
#  '- Do they say ? \n',
#  'That means , \n',
#  'Let see . \n',
#  '- , , , , and , , a , and , , \n',
#  'These are . \n',
#  'When you you all of , , you , you , , \n',
#  '( CHUCKLES ) ) ) ) ) ) ) ) ) ) ) \n',
#  'Just the last thing the same thing \n',
#  'My . \n',
#  'In the old in in in in in in in in in in in in in the work \n',
#  'Maybe maybe ? \n',
#  'Is you see ? \n',
#  "- That 's ... \n",
#  'Our of the you of the are your response of your social - the are your social - and . . \n',
#  '- Yeah ... \n',
#  "This will be on this point on our , I will on n't , with a , \n",
#  'Then to say , going to be fucking like being a fucking year . \n',
#  "I ca n't I n't ! \n",
#  "And there 's there there there there there there there there there there there there there there there there there there 's been no longer on no longer . \n",
#  'This for millions of millions of millions of millions of millions of millions of millions of millions of millions of millions of millions of millions of millions of millions of dollars and education . \n',
#  'Do you think you me you ? \n',
#  'I will I my first to my my when I have to be my on \n',
#  "You n't n't me , me , \n",
#  "And then , it 's it , \n",
#  'Or you man man who were a man . \n',
#  'We have been able to be about a about and things we that about and the to about and and and and and things about the things about our things about and \n',
#  'Now when you were thinking about how to you and when you were and , and this . that . \n',
#  'You you , on , you , you , , you , you , . . . . . \n',
#  'So you you you you , you you you , you you you , you you . . . . . . \n',
#  'He was a a . \n',
#  'They were the my , , and , they , , that they , , and , \n',
#  'All all of all . \n',
#  "That 's every every . \n",
#  'After , all , my , was , , and , , \n',
#  "It 's love . . \n",
#  '( GUN ) ) ) ) \n',
#  'I I not , I but but , but \n',
#  'You hungry ? \n',
#  'In in , in , , in in , that \n',
#  'Here ? \n',
#  "I 'm doing I I this you to you , all on this , \n",
#  'Thanks you . \n',
#  'But the the in -- the and the world is , a world the \n',
#  "So , , 's that , this , before you want to , , \n",
#  "We have n't have to be the \n",
#  'And the family was , and \n',
#  "We 'm doing ! \n",
#  'Mother , Mother . \n',
#  'So this , . \n',
#  "CA : And 's n't you people the n't you \n",
#  'Your Grace , sir . \n',
#  'For this technology , this is a technology . \n',
#  'Right . \n',
#  'But we were just them the \n',
#  'We saw we only seen the \n',
#  'Well ? \n',
#  "I 'll a a a \n",
#  'That means was the \n',
#  'How on the you ! ! \n',
#  '( laughter ) ) ) ) \n',
#  'Sir , we just just can a minutes the \n',
#  'Please sit . \n',
#  'All right . \n',
#  'This is we just both between between . . . \n',
#  '- \n',
#  'You never never can never you never you of you \n',
#  'Here back ! \n',
#  'Look at and look at . \n',
#  'These are " ? \n',
#  'My name is is is . . \n',
#  'We want to at in school , old in -- that and that , old , \n',
#  'Come up . \n',
#  'Tonight tonight . \n',
#  "I 've n't go and I n't you on me you on . \n",
#  'I , how I I work working how working people ? \n',
#  'I felt like the \n',
#  'Whatever or it was a or even or \n',
#  "- I 'm not going anywhere . \n",
#  "( Applause ) ( Applause ) ( 's a ? \n",
#  '- The . \n',
#  'Are you , , you ? \n',
#  'The , who can take the in a , \n',
#  'Just just . \n',
#  'Carly , come . \n',
#  'Thanks , thank you . \n',
#  "I said , I 'm I with you , \n",
#  'Maybe I can probably on the . \n',
#  "It 's just inside inside . \n",
#  'Think about a of and of and and and and and . of . . . . \n',
#  'I I I that \n',
#  'Now ... \n',
#  "Ah , you will be a wrong , wrong 's wrong 's wrong 's wrong 's wrong . \n",
#  'If you know , and you know , of a you know , , of a the , , and . \n',
#  '10 years later , 10 percent since since months later , \n',
#  "You 'll be water , water , you , \n",
#  "And they 'll do n't have a better of life -- ( ) they \n",
#  'And you you now work work \n',
#  "That 's what think it 's . \n",
#  "If you heard about it , when you heard about it , when you 've heard about this , when you 've heard about it , when you do n't know about it , it was a , of \n",
#  'If we can only work together ... \n',
#  'Wake ... \n',
#  '( BOTH ) ) ) ) \n',
#  'Because there there there there there there there there there a there there no way there . \n',
#  '( Applause ) Chris Anderson : ( Applause ) I ? \n',
#  "I 'm a I I a I . \n",
#  "If you , I n't , you , , , , you , I , you , you , \n",
#  'On your side . \n',
#  'With 1 . \n',
#  "Let 's work work . . \n",
#  'Our things , , , , things , and , , and , and things and , , and things and , , and , \n',
#  'But I I and and and and and and and , and and and and and , and and and and . . \n',
#  "Do n't find . . \n",
#  "Why I I you you I n't you \n",
#  'John . \n',
#  "Do n't happened ? \n",
#  'The other is is , \n',
#  "This 's a woman for women who are a woman that women and the \n",
#  "That 's is someone to the \n",
#  "And this 's the , of , , years , , , of , \n",
#  'Great , . \n',
#  'He was the in the , the and the the the . the \n',
#  'Is this ? \n',
#  'Oh , I would I if if I would be you me me if I would be you me \n',
#  "He 's it it . . \n",
#  "You 're not , and and , and \n",
#  'Do you know I think \n',
#  'Three hundred of three . \n',
#  'Jack . \n',
#  "I 'll I I I I . . \n",
#  'The those those those \n',
#  "I 'll kill him . \n",
#  'When you come up ? \n',
#  'Some in , in , , in , of in , , \n',
#  "They 're when they 're . . . . . . \n",
#  '" , , , , " , , " , , " , , " \n',
#  'Have you ever thought about this ? \n',
#  'I I I I I \n',
#  'These are two . \n',
#  "He 'll show her . \n",
#  'What do see ? \n',
#  'But , was of some the , of with , with , who were and , , who with you , who were with , the \n',
#  'And we do we like this . like . . \n',
#  'Why the \n',
#  'But this also even a a a \n',
#  'MAN : \n',
#  'In the of the . \n',
#  'And you of death death . \n',
#  'And ... ... \n',
#  "They 'll have the blood they 're blood ! \n",
#  'She love they love . \n',
#  "I 'll take a a . \n",
#  '- Yeah , that \n',
#  "Come on let let 's . \n",
#  'Why would you take back back in the city ? \n',
#  '( Applause ) \n',
#  "Why do n't you have to ? \n",
#  "[ : And do n't we n't a have a ? \n",
#  'People come together and together with the guys . \n',
#  'If you work , you work , work , are a , you , work , work you , work , \n',
#  'One of a a and of , of and , and . \n',
#  'And science science science science science science science science . \n',
#  "But on , it 's life . \n",
#  '- Okay right ! \n',
#  "Hey , how 's this ? \n",
#  "No , but n't be n't be , , but in , and \n",
#  'We can . \n',
#  'I would have happened to me with , with that \n',
#  "So this 's example , example for example , they 'll have just take a big big , it 's just have to \n",
#  "Yeah , I 'm a a I \n",
#  'Is ? \n',
#  "That 's like , of , looks , \n",
#  '- The the \n',
#  'In air in the air and air air and air and air and air the air \n',
#  "But then , it 's , but the , in the , \n",
#  'This morning morning in the morning morning . \n',
#  'Why I you my ? \n',
#  'These were a really , world in world where they , , and world in world , world in , world world in , world world in , and world in world world , and in world . \n',
#  '3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 . \n',
#  'My my . \n',
#  "It 's all him . \n",
#  "Do n't you n't yourself yourself . \n",
#  'A me , \n',
#  "That 's that they were . . \n",
#  'If you can get someone you can get someone you can get someone you can get on this your side . \n',
#  'The is is is is , most of most of is between the is is is , of of \n',
#  "Do n't n't have n't video that video . \n",
#  'What about the that about ? \n',
#  'In the ! \n',
#  'And I think I think \n',
#  "We 'll a you a . \n",
#  'I need you I need I need to get . \n',
#  'Some I think about about about about about , but I think about about , but about the \n',
#  "I 'm gon na you na just get it to you . \n",
#  'Give it . \n',
#  'In this see of see of these pictures , you see -- and see that the of of . of you . of . of . \n',
#  "She said she 'll be with with with with with \n",
#  'Now , only one of a is , on , \n',
#  "We 're a a -- the -- the . \n",
#  '[ ] ] ] ] \n',
#  '/ . \n',
#  '- She did that . \n',
#  "Let 's a a a a make to the a . . of . . . . . . \n",
#  "You you , you you do n't you , you , \n",
#  '- I I ... that \n',
#  'So the parents to the and , \n',
#  'What do you want to ? \n',
#  'His , I do all with them to all her . \n',
#  'Where think you you you ? \n',
#  'In the economic economic economic growth than the economic economic growth . \n',
#  'And I tried to do this like of the . \n',
#  'No just , just just \n',
#  'In other out of and of with others , in others are , and they are out of and with \n',
#  "Now that night that I ca n't I can night night . \n",
#  '( Applause ) I wanted to I I . . \n',
#  "Come on , let 's let 's . \n",
#  ...]
